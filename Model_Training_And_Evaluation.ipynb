# %% [markdown]
# ## Environment Setup and Imports
# **Purpose**: Initialize the runtime by importing all required libraries and configuring basic settings (e.g., warnings, device selection).

# %%
import gc
import json
import os
import time
import pickle
import warnings
import itertools
import shap
import cudf
import numpy as np
from cuml.ensemble import RandomForestRegressor as cuRF
from cuml.linear_model import Ridge, ElasticNet
import cupy as cp
from lightgbm import LGBMRegressor
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import xgboost as xgb
import itertools
from sklearn.metrics import (
    mean_squared_error,
    mean_absolute_error,
    r2_score,
    median_absolute_error,
    explained_variance_score
)

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Data Loading and Preprocessing
#
# **Purpose**: Read training and test datasets from Parquet files, apply scaling, and add a constant column for OLS modeling.

# %%
train_path = '/data/workspace_files/train_nov/fourth_week_df.parquet'
test_path1 = '/data/workspace_files/test_dec/first_week_df.parquet'
test_path2 = '/data/workspace_files/test_dec/second_week_df.parquet'

scaler = StandardScaler()

X_train = pd.read_parquet(train_path, columns=predictor_cols)
y_train = pd.read_parquet(train_path, columns=['px_imp_5'])

X_test1 = pd.read_parquet(test_path1, columns=predictor_cols)
y_test1 = pd.read_parquet(test_path1, columns=['px_imp_5'])

X_test2 = pd.read_parquet(test_path2, columns=predictor_cols)
y_test2 = pd.read_parquet(test_path2, columns=['px_imp_5'])

X_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_scaled, columns=X_train.columns, index=X_train.index)
X_train = sm.add_constant(X_train)

X_test1_scaled = scaler.transform(X_test1)
X_test1 = pd.DataFrame(X_test1_scaled, columns=X_test1.columns, index=X_test1.index)
X_test1 = sm.add_constant(X_test1)

X_test2_scaled = scaler.transform(X_test2)
X_test2 = pd.DataFrame(X_test2_scaled, columns=X_test2.columns, index=X_test2.index)
X_test2 = sm.add_constant(X_test2)

# %% [markdown]
# ## OLS Model Training and Evaluation
# **Purpose**: Fit an Ordinary Least Squares (OLS) regression model using the preprocessed data, evaluate its performance, and save the computed metrics.

# %%
ols_final = sm.OLS(y_train, X_train).fit(cov_type='HC3')
ols_final.summary()

# %%
metrics_save_dir = '/data/workspace_files/Metrics/OLS'

# Evaluate the model (test data is loaded on demand within evaluate_gbt_model).
y_pred1 = ols_final.predict(X_test1)
metrics1 = compute_regression_metrics(y_test1.values, y_pred1)

# Build a filename for saving metrics that includes all hyperparameters.
metrics_filename = os.path.join(
    metrics_save_dir, 
    f"metrics_final_model_ols_dec1.json"
)
with open(metrics_filename, 'w') as f:
    json.dump(metrics1, f, indent=4)

# Evaluate the model (test data is loaded on demand within evaluate_gbt_model).
y_pred2 = ols_final.predict(X_test2)
metrics2 = compute_regression_metrics(y_test2.values, y_pred2)

# Build a filename for saving metrics that includes all hyperparameters.
metrics_filename = os.path.join(
    metrics_save_dir, 
    f"metrics_final_model_ols_dec2.json"
)
with open(metrics_filename, 'w') as f:
    json.dump(metrics2, f, indent=4)

# %% [markdown]
# ## Model Function Definitions
#
# **Purpose**: Purpose: Define reusable functions for training and evaluating various models (Ridge, ElasticNet, RandomForest, Gradient Boosted Trees, and XGBoost) that load data on demand, perform computations on GPU (if available), and free memory after use.

# %%
def compute_regression_metrics(y_true, y_pred):
    """
    Computeregression metrics and return as a dictionary.
    """
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    medae = median_absolute_error(y_true, y_pred)
    evs = explained_variance_score(y_true, y_pred)
    
    metrics = {
        'MSE': mse,
        'RMSE': rmse,
        'MAE': mae,
        'R2': r2,
        'Median Absolute Error': medae,
        'Explained Variance': evs
    }
    
    return metrics

# %%
# Ridge

def train_ridge_model(train_path, predictor_cols, target_col, alpha):
    """
    Load training data from disk into GPU memory on demand, train a GPU-accelerated
    Ridge model, and free the GPU training data.
    """
    # Load training data directly into GPU memory.
    X_train_gpu = cudf.read_parquet(train_path, columns=predictor_cols)
    y_train_gpu = cudf.read_parquet(train_path, columns=[target_col])
    
    # Training phase on GPU.
    model = Ridge(alpha=alpha)
    model.fit(X_train_gpu, y_train_gpu)
    
    # Free GPU training data.
    del X_train_gpu, y_train_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    return model


def evaluate_ridge_model(model, test_path, predictor_cols, target_col):
    """
    Load test data from disk into GPU memory for features, load target to CPU,
    run prediction on GPU, transfer predictions to CPU, compute regression metrics,
    and free GPU memory.
    """
    # Load test features directly into GPU and target into CPU.
    X_test_gpu = cudf.read_parquet(test_path, columns=predictor_cols)
    y_test_cpu = pd.read_parquet(test_path, columns=[target_col])
    
    # Prediction phase on GPU.
    y_pred_gpu = model.predict(X_test_gpu)
    
    # Free test features from GPU.
    del X_test_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # Transfer predictions from GPU to CPU.
    y_pred_cpu = cp.asnumpy(y_pred_gpu)
    del y_pred_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # Compute regression metrics on CPU.
    metrics = compute_regression_metrics(y_test_cpu.values, y_pred_cpu)
    
    # Clean up CPU objects.
    del y_test_cpu, y_pred_cpu
    gc.collect()
    
    return metrics

# %%
# Elastic Net

def train_elastic_net_model(train_path, predictor_cols, target_col, alpha, l1_ratio):
    """
    Load training data from disk into GPU memory on demand, train a GPU-accelerated
    ElasticNet model, and free the GPU training data.
    """
    # Load training data directly into GPU memory.
    X_train_gpu = cudf.read_parquet(train_path, columns=predictor_cols)
    y_train_gpu = cudf.read_parquet(train_path, columns=[target_col])
    
    # Training phase on GPU.
    model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
    model.fit(X_train_gpu, y_train_gpu)
    
    # Free GPU training data.
    del X_train_gpu, y_train_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    return model


def evaluate_elastic_net_model(model, test_path, predictor_cols, target_col):
    """
    Load test data from disk into GPU memory for features, load target into CPU,
    run prediction on GPU, transfer predictions to CPU, compute regression metrics,
    and free GPU memory.
    """
    # Load test features into GPU and target into CPU.
    X_test_gpu = cudf.read_parquet(test_path, columns=predictor_cols)
    y_test_cpu = pd.read_parquet(test_path, columns=[target_col])
    
    # Prediction phase on GPU.
    y_pred_gpu = model.predict(X_test_gpu)
    
    # Free test features from GPU.
    del X_test_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # Transfer predictions from GPU to CPU.
    y_pred_cpu = cp.asnumpy(y_pred_gpu)
    del y_pred_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # Compute regression metrics on CPU.
    metrics = compute_regression_metrics(y_test_cpu.values, y_pred_cpu)
    
    # Clean up CPU objects.
    del y_test_cpu, y_pred_cpu
    gc.collect()
    
    return metrics

# %%
# RandomForest 

def train_rf_model(train_path, predictor_cols, target_col, n_estimators, max_depth, max_features, max_leaves):
    """
    Load training data from disk into GPU memory on demand, train a GPU-accelerated 
    RandomForest model, and then free the GPU training data.
    """
    # --- Load training data directly into GPU memory ---
    # with open(train_path, 'rb') as f:
    #     X_train_gpu = cudf.read_parquet(f, columns=predictor_cols, engine='pyarrow').astype('float32')
    #     y_train_gpu = cudf.read_parquet(f, columns=[target_col], engine='pyarrow').astype('float32')
    
    X_train_gpu = cudf.read_parquet(train_path, columns=predictor_cols).astype('float32')
    y_train_gpu = cudf.read_parquet(train_path, columns=[target_col]).astype('float32')
    
    # --- Training Phase on GPU ---
    model = cuRF(n_estimators=n_estimators, max_depth=max_depth, random_state=42, n_streams=1)
    model.fit(X_train_gpu, y_train_gpu)
    
    # Free training data from GPU immediately.
    del X_train_gpu, y_train_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    return model


def evaluate_rf_model(model, test_path, predictor_cols, target_col):
    """
    Load test data from disk directly into GPU memory, run prediction with the model,
    then transfer predictions (and ground truth) to the CPU to compute regression metrics.
    """
    # --- Load test data directly into GPU and CPU memory ---
    X_test_gpu = cudf.read_parquet(test_path, columns=predictor_cols).astype('float32')
    y_test_cpu = pd.read_parquet(test_path, columns=[target_col])
    
    # --- Prediction Phase on GPU ---
    y_pred_gpu = model.predict(X_test_gpu)
    
    # Free test features from GPU immediately.
    del X_test_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # --- Transfer predictions and ground truth to CPU ---
    y_pred_cpu = y_pred_gpu.to_pandas()
    del y_pred_gpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # --- Compute regression metrics on CPU ---
    metrics = compute_regression_metrics(y_test_cpu.values, y_pred_cpu.values)
    
    # Clean up CPU objects.
    del y_test_cpu, y_pred_cpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    return metrics

# %%
# Gradient Boosted Trees

def train_gbt_model(train_path, predictor_cols, target_col, 
                    boosting_type, n_estimators, max_depth, learning_rate, num_leaves):
    """
    Load training data from disk into GPU memory on demand, train a LightGBM gradient boosted trees model
    with GPU support, and free the GPU training data.
    """
    # Load training data into GPU.
    # X_train_gpu = cudf.read_parquet(train_path, columns=predictor_cols)
    # y_train_gpu = cudf.read_parquet(train_path, columns=[target_col])
    X_train_cpu = pd.read_parquet(train_path, columns=predictor_cols)
    y_train_cpu = pd.read_parquet(train_path, columns=[target_col])
    
    # Initialize and train the model.
    model = LGBMRegressor(boosting_type=boosting_type, n_estimators=n_estimators, max_depth=max_depth,
                          learning_rate=learning_rate, num_leaves=num_leaves, device='gpu', random_state=42)
    model.fit(X_train_cpu, y_train_cpu)
    
    # Free training data.
    del X_train_cpu, y_train_cpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    return model


def evaluate_gbt_model(model, test_path, predictor_cols, target_col):
    """
    Load test data from disk into GPU memory for features (and target into CPU), 
    convert the features to a pandas DataFrame, run prediction,
    compute regression metrics, and free GPU memory.
    """
    # Load test features into GPU and target into CPU.
    # X_test_gpu = cudf.read_parquet(test_path, columns=predictor_cols)
    X_test_cpu = pd.read_parquet(test_path, columns=predictor_cols)
    y_test_cpu = pd.read_parquet(test_path, columns=[target_col])
    
    # Run prediction on CPU.
    y_pred = model.predict(X_test_cpu)
    
    # Free GPU memory and the intermediate pandas object.
    del X_test_cpu
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()
    gc.collect()
    
    # Compute regression metrics on CPU.
    metrics = compute_regression_metrics(y_test_cpu.values, y_pred)
    
    # Clean up CPU objects.
    del y_test_cpu, y_pred
    gc.collect()
    
    return metrics

# %%
# XG Boost

def train_xgb_model(train_path, predictor_cols, target_col, params, num_boost_round=150):
    """
    Load training data from disk into GPU memory on demand, train an XGBoost model using GPU,
    and free the GPU training data.
    """

    # Load training data directly using pandas.
    X_train = pd.read_parquet(train_path, columns=predictor_cols).values
    y_train = pd.read_parquet(train_path, columns=[target_col]).values
    
    # Create DMatrix from training data.
    dtrain = xgb.DMatrix(X_train, label=y_train)
    
    # Update parameters for CPU training.
    params.update({
        'tree_method': 'hist',
        'n_jobs': -1,
        'booster': 'gbtree',
        'device': 'cpu',
        'objective': 'reg:squarederror',
        'seed': 42
    })
    
    # Train the model.
    booster = xgb.train(params, dtrain, num_boost_round=num_boost_round)
    
    # Clean up.
    del X_train, y_train, dtrain
    gc.collect()
    
    return booster

def evaluate_xgb_model(booster, test_path, predictor_cols, target_col):
    """
    Load test data from disk into GPU memory for features (and target into CPU),
    predict using the XGBoost model, compute regression metrics on CPU, and free GPU memory.
    """

    # Load test data directly using pandas.
    X_test = pd.read_parquet(test_path, columns=predictor_cols).values
    y_test = pd.read_parquet(test_path, columns=[target_col])
    
    # Create DMatrix for testing.
    dtest = xgb.DMatrix(X_test, label=y_test.values)
    
    # Predict using the booster; predictions are on CPU.
    y_pred = booster.predict(dtest)
    
    # Clean up.
    del X_test, dtest
    gc.collect()
    
    # Compute regression metrics on CPU.
    metrics = compute_regression_metrics(y_test.values, y_pred)
    
    # Clean up.
    del y_test, y_pred
    gc.collect()
    
    return metrics

# %% [markdown]
# ## Model Training and Evaluation
#
# **Purpose**: This section is dedicated to training various regression models using the prepared datasets and evaluating their performance. It encompasses model fitting, prediction generation, and metric computation, enabling a systematic comparison across different algorithms and hyperparameter configurations.

# %%
#####################################
# 1. SETUP SECTION
#####################################

# Define predictor columns and target columns.
predictor_cols = [
    'bid', 'spread_minus', 'bbo_moving_trade', 'non_bbo_moving_trade', 'bbo_improving_limit',
    'bbo_worsening_cancel', 'bbo_depth_add_limit', 'bbo_depth_remove_cancel',
    'non_bbo_depth_add_limit', 'non_bbo_depth_remove_cancel', 'non_bbo_deep_depth_add_limit',
    'non_bbo_deep_depth_remove_cancel', 'bbo_depth_imbalance_minus', 
    'non_bbo_depth_imbalance_minus', 'non_bbo_deep_depth_imbalance_minus', 
    'bbo_queue_length_immbalance_minus', 'block_2', 'block_3', 'block_4', 'block_5', 'block_6'
]

# Additional observable features and their replicates.
ob_features = [
    'bbo_moving_trade', 'non_bbo_moving_trade', 'bbo_improving_limit',
    'bbo_worsening_cancel', 'bbo_depth_add_limit', 'bbo_depth_remove_cancel',
    'non_bbo_depth_add_limit', 'non_bbo_depth_remove_cancel', 
    'non_bbo_deep_depth_add_limit', 'non_bbo_deep_depth_remove_cancel'
]
for feat in ob_features:
    for r in range(1, 4):
        predictor_cols.append(f'{feat}_{r}')

# Define target columns
# target_cols = ['px_imp_0', 'px_imp_1', 'px_imp_5', 'px_imp_10', 'px_imp_20']
target_cols = ['px_imp_5']

# Define file paths.
eval_pairs = [('/data/workspace_files/train_oct/oct_train1_df.parquet', '/data/workspace_files/val_oct/oct_val1_df.parquet'),
              ('/data/workspace_files/train_oct/oct_train2_df.parquet', '/data/workspace_files/val_oct/oct_val2_df.parquet'),
              ('/data/workspace_files/train_oct/oct_train3_df.parquet', '/data/workspace_files/val_oct/oct_val3_df.parquet'),
              ('/data/workspace_files/train_oct/oct_train4_df.parquet', '/data/workspace_files/val_oct/oct_val4_df.parquet'),
              ('/data/workspace_files/train_nov/nov_train5_df.parquet', '/data/workspace_files/val_nov/nov_val5_df.parquet'),
              ('/data/workspace_files/train_nov/nov_train6_df.parquet', '/data/workspace_files/val_nov/nov_val6_df.parquet'),
              ('/data/workspace_files/train_nov/nov_train7_df.parquet', '/data/workspace_files/val_nov/nov_val7_df.parquet')]

# Global trackers for overall best result.
overall_best_mse = float('inf')
overall_best_info = None

# Dictionary to track best result per model group (each will be keyed by target)
best_models = {
    'Ridge': {},
    'ElasticNet': {},
    'RandomForest': {},
    'GBM': {},
    'XGBoost': {}
}

# Results list to store all grid search run information.
results = []
model_files_info = []

# %% [markdown]
# ### Random Forest

# %%
model_save_dir = '/data/workspace_files/Models/RF' # '/data/workspace_files/Models/RF'
metrics_save_dir = '/data/workspace_files/Metrics/RF' # '/data/mfe_aaron_afp_eu/Metrics'
os.makedirs(model_save_dir, exist_ok=True)
os.makedirs(metrics_save_dir, exist_ok=True)

#####################################
# 2. TRAINING & EVALUATION LOOP FOR RANDOMFOREST
#####################################

# Hyperparameter grids for RandomForest.
rf_n_estimators = [200] #[100, 200]
rf_max_depths = [20] #[10, 20]
rf_max_features = [1.0] #['sqrt', 1.0]
rf_max_leaves = [-1, 50] #[-1, 50]

print("\nStarting grid search for RandomForest...")

# Create the full grid using itertools.product.
hyperparameter_grid = list(itertools.product(
    rf_n_estimators, rf_max_depths, rf_max_features, rf_max_leaves
))

# Loop over evaluation pairs with an index.
for i, (train_path, test_path) in enumerate(eval_pairs, start=2):
    for target in target_cols:
        print(f"\nProcessing target '{target}' for Eval Pair {i}")

        # Iterate over each combination in the grid.
        for n_estimators, max_depth, max_features, max_leaves in hyperparameter_grid:
            # Print the current set of hyperparameters.
            print(f"  Training RF with n_estimators={n_estimators}, "
                  f"max_depth={max_depth}, max_features={max_features}, "
                  f"max_leaves={max_leaves}...")

            # Train the model.
            model = train_rf_model(
                train_path, predictor_cols, target, 
                n_estimators=n_estimators, max_depth=max_depth,
                max_features=max_features, max_leaves=max_leaves
            )

            # Build filenames that include the target, evaluation pair index, and hyperparameters.
            model_filename = os.path.join(
                model_save_dir,
                f"model_rf_{target}_pair_{i}_nest_{n_estimators}_maxd_{max_depth}_feat_{max_features}_leaves_{max_leaves}.pkl"
            )

            # Save the trained model.
            with open(model_filename, 'wb') as f:
                pickle.dump(model, f)
                print(f"    Model dumped to {model_filename}")

            # Record info for later evaluation.
            info = {
                'eval_pair': i,
                'target': target,
                'train_path': train_path,
                'test_path': test_path,
                'n_estimators': n_estimators,
                'max_depth': max_depth,
                'max_features': max_features,
                'max_leaves': max_leaves,
                'model_file': model_filename
            }
            model_files_info.append(info)

            # Clean up GPU memory after each hyperparameter set.
            cp.get_default_memory_pool().free_all_blocks()
            cp.get_default_pinned_memory_pool().free_all_blocks()
            cp.cuda.Stream.null.synchronize()
            gc.collect()

        # Clean up after each target.
        cp.get_default_memory_pool().free_all_blocks()
        cp.get_default_pinned_memory_pool().free_all_blocks()
        cp.cuda.Stream.null.synchronize()
        gc.collect()

print("\nGrid search for RandomForest completed.")
# Out:
# Starting grid search for RandomForest...
#
# Processing target 'px_imp_5' for Eval Pair 2
#   Training RF with n_estimators=200, max_depth=20, max_features=1.0, max_leaves=-1...
#     Model dumped to /data/workspace_files/Models/RF/model_rf_px_imp_5_pair_2_nest_200_maxd_20_feat_1.0_leaves_-1.pkl
#   Training RF with n_estimators=200, max_depth=20, max_features=1.0, max_leaves=50...
#     Model dumped to /data/workspace_files/Models/RF/model_rf_px_imp_5_pair_2_nest_200_maxd_20_feat_1.0_leaves_50.pkl
#
# Grid search for RandomForest completed.

# %% [markdown]
# Rerun from pair 2 because it crashed
#
#   Training RF with n_estimators=200, max_depth=20, max_features=sqrt, max_leaves=50...
#
# Rerun from pair 3 because it crashed
#
#   Training RF with n_estimators=200, max_depth=20, max_features=1.0, max_leaves=50...

# %%
def populate_model_files_info_from_eval_pairs(model_save_dir, eval_pairs):
    """
    Scans model_save_dir for model files following the naming convention:
    model_rf_{target}_pair_{eval_pair}_nest_{n_estimators}_maxd_{max_depth}_feat_{max_features}_leaves_{max_leaves}.pkl
    """
    model_files_info = []
    # Regex pattern to capture the expected fields.
    pattern = re.compile(
        r"model_rf_(?P<target>.+?)_pair_(?P<eval_pair>\d+)_nest_(?P<n_estimators>\d+)_maxd_(?P<max_depth>\d+)_feat_(?P<max_features>.+?)_leaves_(?P<max_leaves>-?\d+)\.pkl$"
    )
    
    for filename in os.listdir(model_save_dir):
        if filename.endswith('.pkl'):
            match = pattern.match(filename)
            if match:
                info = match.groupdict()
                try:
                    eval_pair = int(info['eval_pair'])
                    # Check if the eval_pair is valid for eval_pairs list.
                    if eval_pair < 1 or eval_pair > len(eval_pairs):
                        print(f"Warning: eval_pair {eval_pair} for file {filename} is out of range. Skipping.")
                        continue
                    
                    n_estimators = int(info['n_estimators'])
                    max_depth = int(info['max_depth'])
                    max_leaves = int(info['max_leaves'])
                    target = info['target']
                    try:
                        max_features = float(info['max_features'])
                    except ValueError:
                        max_features = info['max_features']
                    
                    model_file = os.path.join(model_save_dir, filename)
                    
                    # Use eval_pair to get train and test paths.
                    train_path, test_path = eval_pairs[eval_pair - 1]
                    
                    model_files_info.append({
                        'eval_pair': eval_pair,
                        'target': target,
                        'train_path': train_path,
                        'test_path': test_path,
                        'n_estimators': n_estimators,
                        'max_depth': max_depth,
                        'max_features': max_features,
                        'max_leaves': max_leaves,
                        'model_file': model_file
                    })
                except Exception as e:
                    print(f"Error parsing file {filename}: {e}")
            else:
                print(f"Filename does not match pattern, skipping: {filename}")
    return model_files_info

# %%
eval_pairs = [
    ('/data/workspace_files/train_oct/oct_train1_df.parquet', '/data/workspace_files/val_oct/oct_val1_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train2_df.parquet', '/data/workspace_files/val_oct/oct_val2_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train3_df.parquet', '/data/workspace_files/val_oct/oct_val3_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train4_df.parquet', '/data/workspace_files/val_oct/oct_val4_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train5_df.parquet', '/data/workspace_files/val_nov/nov_val5_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train6_df.parquet', '/data/workspace_files/val_nov/nov_val6_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train7_df.parquet', '/data/workspace_files/val_nov/nov_val7_df.parquet')
]

model_save_dir = '/data/mfe_aaron_afp_eu/Models/RF'
model_files_info = populate_model_files_info_from_eval_pairs(model_save_dir, eval_pairs)

len(model_files_info)
# Out:
# 112

# %%
evaluation_results = []
overall_best_mse = float('inf')
overall_best_info = None


print("\nStarting evaluation loop for RandomForest models...")

total_models = len(model_files_info)
for idx, info in enumerate(model_files_info, start=1):
    print(f"\nProcessing model {idx} of {total_models}...")
    eval_pair    = info['eval_pair']
    target       = info['target']
    test_path    = info['test_path']
    n_estimators = info['n_estimators']
    max_depth    = info['max_depth']
    max_features = info['max_features']
    max_leaves   = info['max_leaves']
    model_filename = info['model_file']
    
    # --- Time the model load ---
    load_start = time.time()
    with open(model_filename, 'rb') as f:
        model = pickle.load(f)
    load_time = time.time() - load_start
    print(f"Model load time: {load_time:.4f} seconds")
    
    # --- Time the prediction step (inside evaluate_rf_model) ---
    pred_start = time.time()
    metrics = evaluate_rf_model(model, test_path, predictor_cols, target)
    pred_time = time.time() - pred_start
    print(f"Prediction time: {pred_time:.4f} seconds")
    
    # Build a filename for saving metrics that includes all hyperparameters.
    metrics_filename = os.path.join(
        metrics_save_dir, 
        f"metrics_rf_{target}_pair_{eval_pair}_nest_{n_estimators}_maxd_{max_depth}_feat_{max_features}_leaves_{max_leaves}.json"
    )
    # Ensure the subdirectory exists.
    os.makedirs(os.path.dirname(metrics_filename), exist_ok=True)
    
    with open(metrics_filename, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    run_info = {
        'eval_pair': eval_pair,
        'target': target,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
        'max_leaves': max_leaves,
        'metrics': metrics,
        'model_file': model_filename,
        'metrics_file': metrics_filename,
        'load_time': load_time,
        'prediction_time': pred_time
    }
    evaluation_results.append(run_info)
    
    # Update overall best if current MSE is lower.
    if metrics['MSE'] < overall_best_mse:
        overall_best_mse = metrics['MSE']
        overall_best_info = run_info
    
    # Clean up.
    gc.collect()
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()

print("\nEvaluation loop for RandomForest models completed.")
# Out:
# Starting evaluation loop for RandomForest models...
#
# Processing model 1 of 112...
# Model load time: 0.2565 seconds
# Prediction time: 7.5543 seconds
#
# Processing model 2 of 112...
# Model load time: 0.2401 seconds
# Prediction time: 3.4987 seconds
#
# Processing model 3 of 112...
# Model load time: 0.3704 seconds
# Prediction time: 4.1325 seconds
#
# Processing model 4 of 112...
# Model load time: 0.2694 seconds
# Prediction time: 2.4657 seconds
#
# Processing model 5 of 112...
# Model load time: 5.1241 seconds
# Prediction time: 5.3784 seconds
#
# Processing model 6 of 112...
# Model load time: 5.0868 seconds
# Prediction time: 4.9759 seconds
#
# Processing model 7 of 112...
# Model load time: 5.6129 seconds
# Prediction time: 3.7442 seconds
#
# Processing model 8 of 112...
# Model load time: 5.7671 seconds
# Prediction time: 5.6871 seconds
#
# Processing model 9 of 112...
# Model load time: 0.4907 seconds
# Prediction time: 2.4546 seconds
#
# Processing model 10 of 112...
# Model load time: 0.6078 seconds
# Prediction time: 3.8046 seconds
#
# Processing model 11 of 112...
# Model load time: 0.4748 seconds
# Prediction time: 4.4649 seconds
#
# Processing model 12 of 112...
# Model load time: 0.4683 seconds
# Prediction time: 3.8239 seconds
#
# Processing model 13 of 112...
# Model load time: 9.2246 seconds
# Prediction time: 8.0456 seconds
#
# Processing model 14 of 112...
# Model load time: 9.2196 seconds
# Prediction time: 8.8844 seconds
#
# Processing model 15 of 112...
# Model load time: 9.5806 seconds
# Prediction time: 7.5890 seconds
#
# Processing model 16 of 112...
# Model load time: 9.1945 seconds
# Prediction time: 7.5516 seconds
#
# Processing model 17 of 112...
# Model load time: 0.3708 seconds
# Prediction time: 7.3456 seconds
#
# Processing model 18 of 112...
# Model load time: 0.3985 seconds
# Prediction time: 4.2348 seconds
#
# Processing model 19 of 112...
# Model load time: 0.3199 seconds
# Prediction time: 4.1120 seconds
#
# Processing model 20 of 112...
# Model load time: 0.4551 seconds
# Prediction time: 4.4273 seconds
#
# Processing model 21 of 112...
# Model load time: 5.0152 seconds
# Prediction time: 4.6070 seconds
#
# Processing model 22 of 112...
# Model load time: 5.2329 seconds
# Prediction time: 3.9963 seconds
#
# Processing model 23 of 112...
# Model load time: 5.1218 seconds
# Prediction time: 5.8563 seconds
#
# Processing model 24 of 112...
# Model load time: 4.8920 seconds
# Prediction time: 3.9702 seconds
#
# Processing model 25 of 112...
# Model load time: 0.5961 seconds
# Prediction time: 6.4004 seconds
#
# Processing model 26 of 112...
# Model load time: 0.4807 seconds
# Prediction time: 2.9016 seconds
#
# Processing model 27 of 112...
# Model load time: 0.4330 seconds
# Prediction time: 4.7037 seconds
#
# Processing model 28 of 112...
# Model load time: 0.6504 seconds
# Prediction time: 7.0014 seconds
#
# Processing model 29 of 112...
# Model load time: 11.1379 seconds
# Prediction time: 9.6171 seconds
#
# Processing model 30 of 112...
# Model load time: 9.0158 seconds
# Prediction time: 9.0347 seconds
#
# Processing model 31 of 112...
# Model load time: 8.9822 seconds
# Prediction time: 9.0459 seconds
#
# Processing model 32 of 112...
# Model load time: 9.3853 seconds
# Prediction time: 10.5916 seconds
#
# Processing model 33 of 112...
# Model load time: 0.4036 seconds
# Prediction time: 6.4610 seconds
#
# Processing model 34 of 112...
# Model load time: 0.4238 seconds
# Prediction time: 3.6975 seconds
#
# Processing model 35 of 112...
# Model load time: 0.2604 seconds
# Prediction time: 2.2539 seconds
#
# Processing model 36 of 112...
# Model load time: 0.3126 seconds
# Prediction time: 3.7600 seconds
#
# Processing model 37 of 112...
# Model load time: 4.4771 seconds
# Prediction time: 3.4314 seconds
#
# Processing model 38 of 112...
# Model load time: 4.2073 seconds
# Prediction time: 3.4714 seconds
#
# Processing model 39 of 112...
# Model load time: 4.1414 seconds
# Prediction time: 4.9623 seconds
#
# Processing model 40 of 112...
# Model load time: 4.1048 seconds
# Prediction time: 4.8739 seconds
#
# Processing model 41 of 112...
# Model load time: 0.4130 seconds
# Prediction time: 2.4503 seconds
#
# Processing model 42 of 112...
# Model load time: 0.3267 seconds
# Prediction time: 4.0720 seconds
#
# Processing model 43 of 112...
# Model load time: 0.3508 seconds
# Prediction time: 4.3235 seconds
#
# Processing model 44 of 112...
# Model load time: 0.4434 seconds
# Prediction time: 4.0839 seconds
#
# Processing model 45 of 112...
# Model load time: 8.4361 seconds
# Prediction time: 9.4491 seconds
#
# Processing model 46 of 112...
# Model load time: 7.3760 seconds
# Prediction time: 7.5674 seconds
#
# Processing model 47 of 112...
# Model load time: 7.7261 seconds
# Prediction time: 8.5164 seconds
#
# Processing model 48 of 112...
# Model load time: 7.1165 seconds
# Prediction time: 9.6446 seconds
#
# Processing model 49 of 112...
# Model load time: 0.3183 seconds
# Prediction time: 5.7529 seconds
#
# Processing model 50 of 112...
# Model load time: 0.3056 seconds
# Prediction time: 2.7638 seconds
#
# Processing model 51 of 112...
# Model load time: 0.2563 seconds
# Prediction time: 2.9536 seconds
#
# Processing model 52 of 112...
# Model load time: 0.3184 seconds
# Prediction time: 3.9381 seconds
#
# Processing model 53 of 112...
# Model load time: 4.1164 seconds
# Prediction time: 4.1909 seconds
#
# Processing model 54 of 112...
# Model load time: 4.8726 seconds
# Prediction time: 2.8866 seconds
#
# Processing model 55 of 112...
# Model load time: 4.9867 seconds
# Prediction time: 3.9296 seconds
#
# Processing model 56 of 112...
# Model load time: 3.9403 seconds
# Prediction time: 2.8737 seconds
#
# Processing model 57 of 112...
# Model load time: 0.4606 seconds
# Prediction time: 3.0156 seconds
#
# Processing model 58 of 112...
# Model load time: 0.3939 seconds
# Prediction time: 1.9586 seconds
#
# Processing model 59 of 112...
# Model load time: 0.3376 seconds
# Prediction time: 2.9897 seconds
#
# Processing model 60 of 112...
# Model load time: 0.4574 seconds
# Prediction time: 1.9662 seconds
#
# Processing model 61 of 112...
# Model load time: 9.1541 seconds
# Prediction time: 6.4433 seconds
#
# Processing model 62 of 112...
# Model load time: 6.9542 seconds
# Prediction time: 7.3908 seconds
#
# Processing model 63 of 112...
# Model load time: 7.6250 seconds
# Prediction time: 5.9814 seconds
#
# Processing model 64 of 112...
# Model load time: 8.1410 seconds
# Prediction time: 6.0340 seconds
#
# Processing model 65 of 112...
# Model load time: 0.3381 seconds
# Prediction time: 6.7206 seconds
#
# Processing model 66 of 112...
# Model load time: 0.4121 seconds
# Prediction time: 4.9973 seconds
#
# Processing model 67 of 112...
# Model load time: 0.3381 seconds
# Prediction time: 6.9182 seconds
#
# Processing model 68 of 112...
# Model load time: 0.2391 seconds
# Prediction time: 5.5180 seconds
#
# Processing model 69 of 112...
# Model load time: 4.8581 seconds
# Prediction time: 7.3103 seconds
#
# Processing model 70 of 112...
# Model load time: 4.6990 seconds
# Prediction time: 6.8164 seconds
#
# Processing model 71 of 112...
# Model load time: 5.3883 seconds
# Prediction time: 4.9193 seconds
#
# Processing model 72 of 112...
# Model load time: 4.7275 seconds
# Prediction time: 6.9596 seconds
#
# Processing model 73 of 112...
# Model load time: 0.4077 seconds
# Prediction time: 3.1264 seconds
#
# Processing model 74 of 112...
# Model load time: 0.3834 seconds
# Prediction time: 6.8703 seconds
#
# Processing model 75 of 112...
# Model load time: 0.5057 seconds
# Prediction time: 5.0756 seconds
#
# Processing model 76 of 112...
# Model load time: 0.4591 seconds
# Prediction time: 3.1400 seconds
#
# Processing model 77 of 112...
# Model load time: 8.8496 seconds
# Prediction time: 13.0420 seconds
#
# Processing model 78 of 112...
# Model load time: 9.7657 seconds
# Prediction time: 12.1174 seconds
#
# Processing model 79 of 112...
# Model load time: 10.1838 seconds
# Prediction time: 12.9507 seconds
#
# Processing model 80 of 112...
# Model load time: 9.1702 seconds
# Prediction time: 10.1926 seconds
#
# Processing model 81 of 112...
# Model load time: 0.3222 seconds
# Prediction time: 5.1998 seconds
#
# Processing model 82 of 112...
# Model load time: 0.4490 seconds
# Prediction time: 3.9952 seconds
#
# Processing model 83 of 112...
# Model load time: 0.3875 seconds
# Prediction time: 2.2627 seconds
#
# Processing model 84 of 112...
# Model load time: 0.3741 seconds
# Prediction time: 3.5324 seconds
#
# Processing model 85 of 112...
# Model load time: 3.6538 seconds
# Prediction time: 3.5122 seconds
#
# Processing model 86 of 112...
# Model load time: 4.2347 seconds
# Prediction time: 3.1571 seconds
#
# Processing model 87 of 112...
# Model load time: 4.9132 seconds
# Prediction time: 4.4302 seconds
#
# Processing model 88 of 112...
# Model load time: 3.6740 seconds
# Prediction time: 4.5073 seconds
#
# Processing model 89 of 112...
# Model load time: 0.5203 seconds
# Prediction time: 5.2784 seconds
#
# Processing model 90 of 112...
# Model load time: 0.5532 seconds
# Prediction time: 3.9037 seconds
#
# Processing model 91 of 112...
# Model load time: 0.4703 seconds
# Prediction time: 2.2957 seconds
#
# Processing model 92 of 112...
# Model load time: 0.4668 seconds
# Prediction time: 3.6457 seconds
#
# Processing model 93 of 112...
# Model load time: 6.9270 seconds
# Prediction time: 7.0676 seconds
#
# Processing model 94 of 112...
# Model load time: 6.5512 seconds
# Prediction time: 7.9430 seconds
#
# Processing model 95 of 112...
# Model load time: 6.2282 seconds
# Prediction time: 6.7259 seconds
#
# Processing model 96 of 112...
# Model load time: 5.7984 seconds
# Prediction time: 7.8565 seconds
#
# Processing model 97 of 112...
# Model load time: 0.3174 seconds
# Prediction time: 2.1446 seconds
#
# Processing model 98 of 112...
# Model load time: 0.2943 seconds
# Prediction time: 6.3050 seconds
#
# Processing model 99 of 112...
# Model load time: 0.2571 seconds
# Prediction time: 5.0896 seconds
#
# Processing model 100 of 112...
# Model load time: 0.3803 seconds
# Prediction time: 2.1370 seconds
#
# Processing model 101 of 112...
# Model load time: 4.1878 seconds
# Prediction time: 5.0137 seconds
#
# Processing model 102 of 112...
# Model load time: 4.1425 seconds
# Prediction time: 4.9660 seconds
#
# Processing model 103 of 112...
# Model load time: 3.9223 seconds
# Prediction time: 4.5286 seconds
#
# Processing model 104 of 112...
# Model load time: 4.1923 seconds
# Prediction time: 4.5828 seconds
#
# Processing model 105 of 112...
# Model load time: 0.5080 seconds
# Prediction time: 3.4839 seconds
#
# Processing model 106 of 112...
# Model load time: 0.3264 seconds
# Prediction time: 3.7397 seconds
#
# Processing model 107 of 112...
# Model load time: 0.3421 seconds
# Prediction time: 3.6344 seconds
#
# Processing model 108 of 112...
# Model load time: 0.5668 seconds
# Prediction time: 2.4189 seconds
#
# Processing model 109 of 112...
# Model load time: 7.6133 seconds
# Prediction time: 9.2006 seconds
#
# Processing model 110 of 112...
# Model load time: 8.0584 seconds
# Prediction time: 7.2340 seconds
#
# Processing model 111 of 112...
# Model load time: 7.8567 seconds
# Prediction time: 7.2325 seconds
#
# Processing model 112 of 112...
# Model load time: 7.6387 seconds
# Prediction time: 7.2523 seconds
#
# Evaluation loop for RandomForest models completed.

# %%
print("\nEvaluation loop completed.")

print("\nOverall Best RandomForest Model:")
print(f"  Eval Pair: {overall_best_info['eval_pair']}")
print(f"  Target: {overall_best_info['target']}")
print(f"  n_estimators: {overall_best_info['n_estimators']}")
print(f"  max_depth: {overall_best_info['max_depth']}")
print(f"  max_features: {overall_best_info['max_features']}")
print(f"  max_leaves: {overall_best_info['max_leaves']}")
print("  Metrics:")
for key, value in overall_best_info['metrics'].items():
    print(f"    {key}: {value}")
print(f"  Model file: {overall_best_info['model_file']}")
print(f"  Metrics file: {overall_best_info['metrics_file']}")

# Optionally, save all evaluation results for future reference.
all_results_filename = os.path.join(metrics_save_dir, "all_evaluation_results.json")
with open(all_results_filename, 'w') as f:
    json.dump(evaluation_results, f, indent=4)

gc.collect()
cp.get_default_memory_pool().free_all_blocks()
cp.get_default_pinned_memory_pool().free_all_blocks()
cp.cuda.Stream.null.synchronize()

# %%
evaluation_results

# %%
cp.get_default_memory_pool().free_all_blocks()
cp.get_default_pinned_memory_pool().free_all_blocks()
cp.cuda.Stream.null.synchronize()
gc.collect()

# %% [markdown]
# ## Gradient Boosted Trees

# %%
# Directories for saving models and metrics.
model_save_dir = '/data/workspace_files/Models/GBT'
metrics_save_dir = '/data/workspace_files/Metrics/GBT'

os.makedirs(model_save_dir, exist_ok=True)
os.makedirs(metrics_save_dir, exist_ok=True)

#####################################
# GRADIENT BOOSTED TREES TRAINING & EVALUATION LOOP
#####################################

# Hyperparameter grids for LightGBM gradient boosted trees.
gbt_boosting_types  = ['gbdt', 'dart']
gbt_n_estimators    = [100, 200, 1000]
gbt_max_depths      = [10, 20]
gbt_learning_rates  = [0.05, 0.1]
gbt_num_leaves      = [31] # [50]

print("\nStarting grid search for Gradient Boosted Trees...")

# Create the full grid using itertools.product.
hyperparameter_grid = list(itertools.product(
    gbt_boosting_types, gbt_n_estimators, gbt_max_depths, gbt_learning_rates, gbt_num_leaves
))
print(f"Total grid points: {len(hyperparameter_grid)}")

# Loop over evaluation pairs with an index.
for i, (train_path, test_path) in enumerate(eval_pairs, start=1):
    for target in target_cols:
        print(f"\nProcessing target '{target}' for Eval Pair {i}")
        for boosting, n_estimators, max_depth, learning_rate, num_leaves in hyperparameter_grid:
            # Print the current set of hyperparameters.
            print(f"  Training GBT with boosting_type={boosting}, n_estimators={n_estimators}, "
                  f"max_depth={max_depth}, learning_rate={learning_rate}, num_leaves={num_leaves}...")
            
            # Train the model.
            model = train_gbt_model(
                train_path, predictor_cols, target,
                boosting_type=boosting,
                n_estimators=n_estimators,
                max_depth=max_depth,
                learning_rate=learning_rate,
                num_leaves=num_leaves
            )
            
            # Build filename that includes target, evaluation pair, and hyperparameters.
            model_filename = os.path.join(
                model_save_dir,
                f"model_gbt_{target}_pair_{i}_boost_{boosting}_nest_{n_estimators}_maxd_{max_depth}_lr_{learning_rate}_leaves_{num_leaves}.pkl"
            )
            
            # Save the trained model.
            with open(model_filename, 'wb') as f:
                pickle.dump(model, f)
                print(f"    Model dumped to {model_filename}")
            
            # Record info for later evaluation.
            info = {
                'eval_pair': i,
                'target': target,
                'train_path': train_path,
                'test_path': test_path,
                'boosting_type': boosting,
                'n_estimators': n_estimators,
                'max_depth': max_depth,
                'learning_rate': learning_rate,
                'num_leaves': num_leaves,
                'model_file': model_filename
            }
            model_files_info.append(info)
            
            # Clean up GPU memory after each hyperparameter set.
            cp.get_default_memory_pool().free_all_blocks()
            cp.get_default_pinned_memory_pool().free_all_blocks()
            cp.cuda.Stream.null.synchronize()
            gc.collect()
        
        # Clean up after each target.
        cp.get_default_memory_pool().free_all_blocks()
        cp.get_default_pinned_memory_pool().free_all_blocks()
        cp.cuda.Stream.null.synchronize()
        gc.collect()

print("\nGrid search for Gradient Boosted Trees completed.")
# Out:
# Starting grid search for Gradient Boosted Trees...
# Total grid points: 1
#
# Processing target 'px_imp_5' for Eval Pair 5
#   Training GBT with boosting_type=dart, n_estimators=1000, max_depth=20, learning_rate=0.1, num_leaves=31...
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 1217
# [LightGBM] [Info] Number of data points in the train set: 13043266, number of used features: 51
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 10 dense feature groups (149.27 MB) transferred to GPU in 0.178255 secs. 1 sparse feature groups
# [LightGBM] [Info] Start training from score -0.000000
#     Model dumped to /data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl
#
# Grid search for Gradient Boosted Trees completed.

# %%
import os
import re
import pprint

def populate_model_files_info_from_eval_pairs_gbt(model_save_dir, eval_pairs):
    """
    Scans model_save_dir for GBT model files following the naming convention:
    model_gbt_{target}_pair_{eval_pair}_boost_{boosting_type}_nest_{n_estimators}_maxd_{max_depth}_lr_{learning_rate}_leaves_{num_leaves}.pkl
    """
    model_files_info = []
    # Regex pattern for GBT model files.
    pattern = re.compile(
        r"model_gbt_(?P<target>.+?)(?=_pair_)_pair_(?P<eval_pair>\d+)_boost_(?P<boosting_type>.+?)(?=_nest_)_nest_(?P<n_estimators>\d+)_maxd_(?P<max_depth>\d+)_lr_(?P<learning_rate>.+?)(?=_leaves_)_leaves_(?P<num_leaves>\d+)\.pkl$"
    )
    
    for filename in os.listdir(model_save_dir):
        if filename.endswith('.pkl'):
            match = pattern.match(filename)
            if match:
                info = match.groupdict()
                try:
                    eval_pair = int(info['eval_pair'])
                    # Check if the eval_pair is valid.
                    if eval_pair < 1 or eval_pair > len(eval_pairs):
                        print(f"Warning: eval_pair {eval_pair} for file {filename} is out of range. Skipping.")
                        continue
                    
                    n_estimators = int(info['n_estimators'])
                    max_depth = int(info['max_depth'])
                    num_leaves = int(info['num_leaves'])
                    target = info['target']
                    boosting_type = info['boosting_type']
                    try:
                        learning_rate = float(info['learning_rate'])
                    except ValueError:
                        learning_rate = info['learning_rate']
                    
                    model_file = os.path.join(model_save_dir, filename)
                    
                    # Use eval_pair to get train and test paths.
                    train_path, test_path = eval_pairs[eval_pair - 1]
                    
                    model_files_info.append({
                        'eval_pair': eval_pair,
                        'target': target,
                        'boosting_type': boosting_type,
                        'train_path': train_path,
                        'test_path': test_path,
                        'n_estimators': n_estimators,
                        'max_depth': max_depth,
                        'learning_rate': learning_rate,
                        'num_leaves': num_leaves,
                        'model_file': model_file
                    })
                except Exception as e:
                    print(f"Error parsing file {filename}: {e}")
            else:
                print(f"Filename does not match pattern, skipping: {filename}")
    return model_files_info

# Example usage:
eval_pairs = [
    ('/data/workspace_files/train_oct/oct_train1_df.parquet', '/data/workspace_files/val_oct/oct_val1_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train2_df.parquet', '/data/workspace_files/val_oct/oct_val2_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train3_df.parquet', '/data/workspace_files/val_oct/oct_val3_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train4_df.parquet', '/data/workspace_files/val_oct/oct_val4_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train5_df.parquet', '/data/workspace_files/val_nov/nov_val5_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train6_df.parquet', '/data/workspace_files/val_nov/nov_val6_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train7_df.parquet', '/data/workspace_files/val_nov/nov_val7_df.parquet')
]

model_save_dir = '/data/workspace_files/Models/GBT'
model_files_info = populate_model_files_info_from_eval_pairs_gbt(model_save_dir, eval_pairs)
pprint.pprint(model_files_info)
# Out:
# [{'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
# ...
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 1,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 4,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_1000_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 1,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val1_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train1_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 2,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_1000_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 2,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val2_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train2_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 5,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val5_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train5_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_1000_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 4,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_1000_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 1000,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val4_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train4_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.05,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 3,
#   'learning_rate': 0.1,
#   'max_depth': 10,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_oct/oct_val3_df.parquet',
#   'train_path': '/data/workspace_files/train_oct/oct_train3_df.parquet'},
#  {'boosting_type': 'dart',
#   'eval_pair': 6,
#   'learning_rate': 0.05,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'n_estimators': 100,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val6_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train6_df.parquet'},
#  {'boosting_type': 'gbdt',
#   'eval_pair': 7,
#   'learning_rate': 0.1,
#   'max_depth': 20,
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'n_estimators': 200,
#   'num_leaves': 31,
#   'target': 'px_imp_5',
#   'test_path': '/data/workspace_files/val_nov/nov_val7_df.parquet',
#   'train_path': '/data/workspace_files/train_nov/nov_train7_df.parquet'}]

# %%
evaluation_results = []
overall_best_mse = float('inf')
overall_best_info = None

print("\nStarting evaluation loop for Gradient Boosted Trees models...")

total_models = len(model_files_info)
for idx, info in enumerate(model_files_info, start=1):
    print(f"\nProcessing model {idx} of {total_models}...")
    eval_pair     = info['eval_pair']
    target        = info['target']
    test_path     = info['test_path']
    boosting_type = info['boosting_type']
    n_estimators  = info['n_estimators']
    max_depth     = info['max_depth']
    learning_rate = info['learning_rate']
    num_leaves    = info['num_leaves']
    model_filename = info['model_file']

    # Build metrics filename.
    metrics_filename = os.path.join(
        metrics_save_dir, 
        f"metrics_gbt_{target}_pair_{eval_pair}_boost_{boosting_type}_nest_{n_estimators}_maxd_{max_depth}_lr_{learning_rate}_leaves_{num_leaves}.json"
    )
    # If the metrics file exists, skip this model.
    if os.path.exists(metrics_filename):
        print(f"Metrics file {metrics_filename} already exists. Skipping model {idx}.")
        continue

    # --- Time the model load ---
    load_start = time.time()
    with open(model_filename, 'rb') as f:
        model = pickle.load(f)
    load_time = time.time() - load_start
    print(f"Model load time: {load_time:.4f} seconds")
    
    # --- Time the prediction step (inside evaluate_gbt_model) ---
    pred_start = time.time()
    metrics = evaluate_gbt_model(model, test_path, predictor_cols, target)
    pred_time = time.time() - pred_start
    print(f"Prediction time: {pred_time:.4f} seconds")
    
    # Ensure the directory for metrics file exists.
    os.makedirs(os.path.dirname(metrics_filename), exist_ok=True)
    
    with open(metrics_filename, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    run_info = {
        'eval_pair': eval_pair,
        'target': target,
        'boosting_type': boosting_type,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'learning_rate': learning_rate,
        'num_leaves': num_leaves,
        'metrics': metrics,
        'model_file': model_filename,
        'metrics_file': metrics_filename
    }
    evaluation_results.append(run_info)
    
    # Update overall best if current MSE is lower.
    if metrics['MSE'] < overall_best_mse:
        overall_best_mse = metrics['MSE']
        overall_best_info = run_info

    # Clean up.
    gc.collect()
    cp.get_default_memory_pool().free_all_blocks()
    cp.get_default_pinned_memory_pool().free_all_blocks()
    cp.cuda.Stream.null.synchronize()

print("\nEvaluation loop for Gradient Boosted Trees models completed.")
# Out:
# Starting evaluation loop for Gradient Boosted Trees models...
#
# Processing model 1 of 168...
#
# Processing model 2 of 168...
#
# Processing model 3 of 168...
#
# Processing model 4 of 168...
#
# Processing model 5 of 168...
#
# Processing model 6 of 168...
#
# Processing model 7 of 168...
#
# Processing model 8 of 168...
#
# Processing model 9 of 168...
#
# Processing model 10 of 168...
#
# Processing model 11 of 168...
#
# Processing model 12 of 168...
#
# Processing model 13 of 168...
#
# Processing model 14 of 168...
#
# Processing model 15 of 168...
#
# Processing model 16 of 168...
#
# Processing model 17 of 168...
#
# Processing model 18 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 18.
#
# Processing model 19 of 168...
#
# Processing model 20 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 20.
#
# Processing model 21 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 21.
#
# Processing model 22 of 168...
#
# Processing model 23 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 23.
#
# Processing model 24 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 24.
#
# Processing model 25 of 168...
#
# Processing model 26 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 26.
#
# Processing model 27 of 168...
#
# Processing model 28 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 28.
#
# Processing model 29 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 29.
#
# Processing model 30 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 30.
#
# Processing model 31 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 31.
#
# Processing model 32 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 32.
#
# Processing model 33 of 168...
#
# Processing model 34 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 34.
#
# Processing model 35 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 35.
#
# Processing model 36 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 36.
#
# Processing model 37 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 37.
#
# Processing model 38 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 38.
#
# Processing model 39 of 168...
#
# Processing model 40 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 40.
#
# Processing model 41 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 41.
#
# Processing model 42 of 168...
#
# Processing model 43 of 168...
#
# Processing model 44 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 44.
#
# Processing model 45 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 45.
#
# Processing model 46 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 46.
#
# Processing model 47 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 47.
#
# Processing model 48 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 48.
#
# Processing model 49 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 49.
#
# Processing model 50 of 168...
#
# Processing model 51 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 51.
#
# Processing model 52 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 52.
#
# Processing model 53 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 53.
#
# Processing model 54 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 54.
#
# Processing model 55 of 168...
#
# Processing model 56 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 56.
#
# Processing model 57 of 168...
#
# Processing model 58 of 168...
#
# Processing model 59 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 59.
#
# Processing model 60 of 168...
#
# Processing model 61 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 61.
#
# Processing model 62 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 62.
#
# Processing model 63 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 63.
#
# Processing model 64 of 168...
#
# Processing model 65 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 65.
#
# Processing model 66 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 66.
#
# Processing model 67 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 67.
#
# Processing model 68 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 68.
#
# Processing model 69 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 69.
#
# Processing model 70 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 70.
#
# Processing model 71 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 71.
#
# Processing model 72 of 168...
#
# Processing model 73 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 73.
#
# Processing model 74 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 74.
#
# Processing model 75 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 75.
#
# Processing model 76 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 76.
#
# Processing model 77 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 77.
#
# Processing model 78 of 168...
#
# Processing model 79 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 79.
#
# Processing model 80 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 80.
#
# Processing model 81 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 81.
#
# Processing model 82 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 82.
#
# Processing model 83 of 168...
#
# Processing model 84 of 168...
#
# Processing model 85 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 85.
#
# Processing model 86 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 86.
#
# Processing model 87 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 87.
#
# Processing model 88 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 88.
#
# Processing model 89 of 168...
#
# Processing model 90 of 168...
#
# Processing model 91 of 168...
#
# Processing model 92 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 92.
#
# Processing model 93 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 93.
#
# Processing model 94 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 94.
#
# Processing model 95 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 95.
#
# Processing model 96 of 168...
#
# Processing model 97 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 97.
#
# Processing model 98 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 98.
#
# Processing model 99 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 99.
#
# Processing model 100 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 100.
#
# Processing model 101 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 101.
#
# Processing model 102 of 168...
#
# Processing model 103 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 103.
#
# Processing model 104 of 168...
#
# Processing model 105 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 105.
#
# Processing model 106 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 106.
#
# Processing model 107 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 107.
#
# Processing model 108 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 108.
#
# Processing model 109 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 109.
#
# Processing model 110 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 110.
#
# Processing model 111 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 111.
#
# Processing model 112 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 112.
#
# Processing model 113 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 113.
#
# Processing model 114 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 114.
#
# Processing model 115 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 115.
#
# Processing model 116 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 116.
#
# Processing model 117 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 117.
#
# Processing model 118 of 168...
#
# Processing model 119 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 119.
#
# Processing model 120 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 120.
#
# Processing model 121 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 121.
#
# Processing model 122 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 122.
#
# Processing model 123 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 123.
#
# Processing model 124 of 168...
#
# Processing model 125 of 168...
#
# Processing model 126 of 168...
#
# Processing model 127 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 127.
#
# Processing model 128 of 168...
#
# Processing model 129 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 129.
#
# Processing model 130 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 130.
#
# Processing model 131 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 131.
#
# Processing model 132 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 132.
#
# Processing model 133 of 168...
#
# Processing model 134 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 134.
#
# Processing model 135 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 135.
#
# Processing model 136 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 136.
#
# Processing model 137 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 137.
#
# Processing model 138 of 168...
#
# Processing model 139 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 139.
#
# Processing model 140 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 140.
#
# Processing model 141 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 141.
#
# Processing model 142 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 142.
#
# Processing model 143 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 143.
#
# Processing model 144 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 144.
#
# Processing model 145 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 145.
#
# Processing model 146 of 168...
#
# Processing model 147 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 147.
#
# Processing model 148 of 168...
#
# Processing model 149 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 149.
#
# Processing model 150 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 150.
#
# Processing model 151 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 151.
#
# Processing model 152 of 168...
#
# Processing model 153 of 168...
#
# Processing model 154 of 168...
#
# Processing model 155 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 155.
#
# Processing model 156 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 156.
#
# Processing model 157 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 157.
#
# Processing model 158 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 158.
#
# Processing model 159 of 168...
#
# Processing model 160 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 160.
#
# Processing model 161 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 161.
#
# Processing model 162 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 162.
#
# Processing model 163 of 168...
#
# Processing model 164 of 168...
#
# Processing model 165 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json already exists. Skipping model 165.
#
# Processing model 166 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json already exists. Skipping model 166.
#
# Processing model 167 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json already exists. Skipping model 167.
#
# Processing model 168 of 168...
# Metrics file /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json already exists. Skipping model 168.
#
# Evaluation loop for Gradient Boosted Trees models completed.

# %%
print("\nEvaluation loop completed.")

print("\nOverall Best Gradient Boosted Trees Model:")
print(f"  Eval Pair: {overall_best_info['eval_pair']}")
print(f"  Target: {overall_best_info['target']}")
print(f"  Boosting Type: {overall_best_info['boosting_type']}")
print(f"  n_estimators: {overall_best_info['n_estimators']}")
print(f"  max_depth: {overall_best_info['max_depth']}")
print(f"  learning_rate: {overall_best_info['learning_rate']}")
print(f"  num_leaves: {overall_best_info['num_leaves']}")
print("  Metrics:")
for key, value in overall_best_info['metrics'].items():
    print(f"    {key}: {value}")
print(f"  Model file: {overall_best_info['model_file']}")
print(f"  Metrics file: {overall_best_info['metrics_file']}")

# Optionally, save all evaluation results for future reference.
all_results_filename = os.path.join(metrics_save_dir, "all_evaluation_results.json")
with open(all_results_filename, 'w') as f:
    json.dump(evaluation_results, f, indent=4)

gc.collect()
cp.get_default_memory_pool().free_all_blocks()
cp.get_default_pinned_memory_pool().free_all_blocks()
cp.cuda.Stream.null.synchronize()
# Out:
# Evaluation loop completed.
#
# Overall Best Gradient Boosted Trees Model:
#   Eval Pair: 3
#   Target: px_imp_5
#   Boosting Type: dart
#   n_estimators: 1000
#   max_depth: 10
#   learning_rate: 0.05
#   num_leaves: 31
#   Metrics:
#     MSE: 9.663882695403778e-09
#     RMSE: 9.830504918570449e-05
#     MAE: 2.7687421159721706e-05
#     R2: 0.07723891184694753
#     Median Absolute Error: 5.753558629481704e-06
#     Explained Variance: 0.07725600471389205
#   Model file: /data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.pkl
#   Metrics file: /data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_1000_maxd_10_lr_0.05_leaves_31.json

# %%
evaluation_results
# Out:
# [{'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7800554737406772e-08,
#    'RMSE': np.float64(0.00013341871959139307),
#    'MAE': 4.0724083058962924e-05,
#    'R2': 0.10800277321394769,
#    'Median Absolute Error': np.float64(8.627593963205301e-06),
#    'Explained Variance': 0.10802573466565424},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7833444765171383e-08,
#    'RMSE': np.float64(0.00013354192137741386),
#    'MAE': 4.080611939190233e-05,
#    'R2': 0.10635463280553126,
#    'Median Absolute Error': np.float64(8.775286435002407e-06),
#    'Explained Variance': 0.10637347611149461},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.781889477973236e-08,
#    'RMSE': np.float64(0.000133487433040464),
#    'MAE': 4.068701130732888e-05,
#    'R2': 0.10708374191773828,
#    'Median Absolute Error': np.float64(8.758391768805038e-06),
#    'Explained Variance': 0.10710581557494558},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.789140614837247e-08,
#    'RMSE': np.float64(0.00013375876101539094),
#    'MAE': 4.08220129189028e-05,
#    'R2': 0.10345015067906083,
#    'Median Absolute Error': np.float64(8.88935595359855e-06),
#    'Explained Variance': 0.1034693534751635},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7807623407234477e-08,
#    'RMSE': np.float64(0.00013344520750942866),
#    'MAE': 4.076735844814212e-05,
#    'R2': 0.10764855763042269,
#    'Median Absolute Error': np.float64(8.605630275359977e-06),
#    'Explained Variance': 0.10766468824949171},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7946840041170295e-08,
#    'RMSE': np.float64(0.00013396581668907295),
#    'MAE': 4.087127086474895e-05,
#    'R2': 0.10067232271948023,
#    'Median Absolute Error': np.float64(8.570563974607979e-06),
#    'Explained Variance': 0.10068948967206737},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7843249038470248e-08,
#    'RMSE': np.float64(0.00013357862493105043),
#    'MAE': 4.0725181478445106e-05,
#    'R2': 0.10586333437566464,
#    'Median Absolute Error': np.float64(8.726523758342914e-06),
#    'Explained Variance': 0.10588099619006874},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7964649760140717e-08,
#    'RMSE': np.float64(0.00013403227133843818),
#    'MAE': 4.0874340408873434e-05,
#    'R2': 0.09977986626709379,
#    'Median Absolute Error': np.float64(8.662282445893257e-06),
#    'Explained Variance': 0.09979373755788412},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.825154150482093e-08,
#    'RMSE': np.float64(0.00013509826610590134),
#    'MAE': 3.949781914176743e-05,
#    'R2': 0.08540353674154322,
#    'Median Absolute Error': np.float64(7.267069789270088e-06),
#    'Explained Variance': 0.0854118990683399},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7919772397258682e-08,
#    'RMSE': np.float64(0.00013386475412616527),
#    'MAE': 3.994318998588473e-05,
#    'R2': 0.1020286997347456,
#    'Median Absolute Error': np.float64(7.502607198897078e-06),
#    'Explained Variance': 0.10204647432699876},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.8258876333481356e-08,
#    'RMSE': np.float64(0.00013512540965148398),
#    'MAE': 3.949052729672963e-05,
#    'R2': 0.08503598376802246,
#    'Median Absolute Error': np.float64(7.2380402118239135e-06),
#    'Explained Variance': 0.08504448677972143},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7966348496175786e-08,
#    'RMSE': np.float64(0.00013403860822977753),
#    'MAE': 4.008918979740699e-05,
#    'R2': 0.09969474151369839,
#    'Median Absolute Error': np.float64(7.811611076300662e-06),
#    'Explained Variance': 0.09971310051309523},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.81003898455756e-08,
#    'RMSE': np.float64(0.0001345376893126071),
#    'MAE': 3.959124993538282e-05,
#    'R2': 0.09297784343366078,
#    'Median Absolute Error': np.float64(7.439530891893753e-06),
#    'Explained Variance': 0.09298914495898458},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.7907922258832754e-08,
#    'RMSE': np.float64(0.0001338204851987645),
#    'MAE': 4.005925477424631e-05,
#    'R2': 0.10262251777968234,
#    'Median Absolute Error': np.float64(7.587232882527935e-06),
#    'Explained Variance': 0.10264093967922738},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.8113264116024386e-08,
#    'RMSE': np.float64(0.00013458552714175616),
#    'MAE': 3.959795066388902e-05,
#    'R2': 0.09233270547551164,
#    'Median Absolute Error': np.float64(7.313538692905482e-06),
#    'Explained Variance': 0.09234439757474344},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 1,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.78980778281257e-08,
#    'RMSE': np.float64(0.0001337836979161725),
#    'MAE': 4.009014200152943e-05,
#    'R2': 0.10311582852305645,
#    'Median Absolute Error': np.float64(7.727109152516792e-06),
#    'Explained Variance': 0.10313343136154618},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_1_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3282776432198446e-08,
#    'RMSE': np.float64(0.00011525092811859888),
#    'MAE': 3.3012750629407435e-05,
#    'R2': 0.09125202782295838,
#    'Median Absolute Error': np.float64(6.9493489095090735e-06),
#    'Explained Variance': 0.09125550853324083},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3356274384955491e-08,
#    'RMSE': np.float64(0.0001155693488125441),
#    'MAE': 3.3211461959825026e-05,
#    'R2': 0.0862236276335806,
#    'Median Absolute Error': np.float64(7.116123482930698e-06),
#    'Explained Variance': 0.08622507147642133},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.329807722920298e-08,
#    'RMSE': np.float64(0.00011531728937675816),
#    'MAE': 3.3030174188659137e-05,
#    'R2': 0.09020521593678843,
#    'Median Absolute Error': np.float64(6.967779123650573e-06),
#    'Explained Variance': 0.09020807116884388},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3360754282274313e-08,
#    'RMSE': np.float64(0.00011558872904515524),
#    'MAE': 3.318603168537323e-05,
#    'R2': 0.08591713315745808,
#    'Median Absolute Error': np.float64(7.023086716639492e-06),
#    'Explained Variance': 0.08591986221723436},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3343601171685856e-08,
#    'RMSE': np.float64(0.00011551450632576783),
#    'MAE': 3.322604824199193e-05,
#    'R2': 0.08709067202889476,
#    'Median Absolute Error': np.float64(7.150487032204876e-06),
#    'Explained Variance': 0.08709243734395222},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.347700582693379e-08,
#    'RMSE': np.float64(0.00011609050704917173),
#    'MAE': 3.341579332092744e-05,
#    'R2': 0.07796372401811114,
#    'Median Absolute Error': np.float64(7.146128794664092e-06),
#    'Explained Variance': 0.07796379628205974},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3350436675643724e-08,
#    'RMSE': np.float64(0.00011554408974778297),
#    'MAE': 3.321464536258163e-05,
#    'R2': 0.08662301751462753,
#    'Median Absolute Error': np.float64(7.142179464465424e-06),
#    'Explained Variance': 0.08662514974947988},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3462879315057742e-08,
#    'RMSE': np.float64(0.00011602964843115634),
#    'MAE': 3.341851709450671e-05,
#    'R2': 0.07893019658405565,
#    'Median Absolute Error': np.float64(7.124840345285986e-06),
#    'Explained Variance': 0.07893040721266298},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3639683368266898e-08,
#    'RMSE': np.float64(0.00011678905500202875),
#    'MAE': 3.1978954304718416e-05,
#    'R2': 0.06683405647007867,
#    'Median Absolute Error': np.float64(5.290088955921161e-06),
#    'Explained Variance': 0.06684132506727991},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3403279906957139e-08,
#    'RMSE': np.float64(0.00011577253520139022),
#    'MAE': 3.251431407554289e-05,
#    'R2': 0.08300772070191131,
#    'Median Absolute Error': np.float64(6.186651880592326e-06),
#    'Explained Variance': 0.08301427467190081},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3640898623660603e-08,
#    'RMSE': np.float64(0.00011679425766560873),
#    'MAE': 3.203691385689576e-05,
#    'R2': 0.0667509141481143,
#    'Median Absolute Error': np.float64(5.192837008430209e-06),
#    'Explained Variance': 0.06675818222611685},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3417411698414014e-08,
#    'RMSE': np.float64(0.0001158335516955861),
#    'MAE': 3.248945887996528e-05,
#    'R2': 0.08204088693073275,
#    'Median Absolute Error': np.float64(6.1036455332588755e-06),
#    'Explained Variance': 0.08204665594153138},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.353758393983598e-08,
#    'RMSE': np.float64(0.0001163511235005317),
#    'MAE': 3.217907677017368e-05,
#    'R2': 0.07381924130855266,
#    'Median Absolute Error': np.float64(5.441376766785552e-06),
#    'Explained Variance': 0.0738264503667102},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3356481316276911e-08,
#    'RMSE': np.float64(0.00011557024407812294),
#    'MAE': 3.262331553053119e-05,
#    'R2': 0.0862094703209374,
#    'Median Absolute Error': np.float64(6.338788995203028e-06),
#    'Explained Variance': 0.08621576059472935},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3529463821879361e-08,
#    'RMSE': np.float64(0.00011631622338212053),
#    'MAE': 3.215553594234869e-05,
#    'R2': 0.07437478334937386,
#    'Median Absolute Error': np.float64(5.43750572646892e-06),
#    'Explained Variance': 0.07438153939036629},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 2,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.3375461112472119e-08,
#    'RMSE': np.float64(0.00011565232860808345),
#    'MAE': 3.263363641695461e-05,
#    'R2': 0.08491095781545566,
#    'Median Absolute Error': np.float64(6.2629921133080384e-06),
#    'Explained Variance': 0.08491633029150736},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_2_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.630418624267832e-09,
#    'RMSE': np.float64(9.813469633247881e-05),
#    'MAE': 2.763537914733789e-05,
#    'R2': 0.08043424685552791,
#    'Median Absolute Error': np.float64(5.753184704466168e-06),
#    'Explained Variance': 0.08044714150888421},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.672204602300217e-09,
#    'RMSE': np.float64(9.834736703288104e-05),
#    'MAE': 2.7892917908698493e-05,
#    'R2': 0.07644429004685893,
#    'Median Absolute Error': np.float64(6.110236164983688e-06),
#    'Explained Variance': 0.07646677010990832},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.62845797936714e-09,
#    'RMSE': np.float64(9.812470626385152e-05),
#    'MAE': 2.763733624619061e-05,
#    'R2': 0.08062146009880367,
#    'Median Absolute Error': np.float64(5.701948134007209e-06),
#    'Explained Variance': 0.0806338038446921},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.720945666198607e-09,
#    'RMSE': np.float64(9.859485618529299e-05),
#    'MAE': 2.7891377901491005e-05,
#    'R2': 0.07179022308658778,
#    'Median Absolute Error': np.float64(6.212699691589379e-06),
#    'Explained Variance': 0.07180945136583339},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.660228063319506e-09,
#    'RMSE': np.float64(9.828645920633984e-05),
#    'MAE': 2.783772807882645e-05,
#    'R2': 0.07758787637654452,
#    'Median Absolute Error': np.float64(6.138100874198982e-06),
#    'Explained Variance': 0.07760854906854098},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.782826960740863e-09,
#    'RMSE': np.float64(9.890817438786778e-05),
#    'MAE': 2.808534512191055e-05,
#    'R2': 0.06588145406611001,
#    'Median Absolute Error': np.float64(6.082194260434415e-06),
#    'Explained Variance': 0.06589090853542245},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.684956277047619e-09,
#    'RMSE': np.float64(9.841217545125002e-05),
#    'MAE': 2.7849725890436203e-05,
#    'R2': 0.07522668945747235,
#    'Median Absolute Error': np.float64(6.088497932338442e-06),
#    'Explained Variance': 0.07524892039763831},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.816837755534386e-09,
#    'RMSE': np.float64(9.90799563763246e-05),
#    'MAE': 2.8109571709050386e-05,
#    'R2': 0.06263391485213055,
#    'Median Absolute Error': np.float64(6.284776885245054e-06),
#    'Explained Variance': 0.0626524777313866},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.811950846088068e-09,
#    'RMSE': np.float64(9.905529186312092e-05),
#    'MAE': 2.6745818543016983e-05,
#    'R2': 0.06310054405495957,
#    'Median Absolute Error': np.float64(4.583492660605515e-06),
#    'Explained Variance': 0.06310305198917965},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.670281147497548e-09,
#    'RMSE': np.float64(9.833758766360677e-05),
#    'MAE': 2.7174253154060145e-05,
#    'R2': 0.07662795217342522,
#    'Median Absolute Error': np.float64(5.1367413619747646e-06),
#    'Explained Variance': 0.07663519956809206},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.818536948847298e-09,
#    'RMSE': np.float64(9.90885308643099e-05),
#    'MAE': 2.6732837856549512e-05,
#    'R2': 0.06247166645572266,
#    'Median Absolute Error': np.float64(4.937788117074641e-06),
#    'Explained Variance': 0.06247426271937295},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.673245835739064e-09,
#    'RMSE': np.float64(9.835266054225002e-05),
#    'MAE': 2.714123851792479e-05,
#    'R2': 0.0763448673064,
#    'Median Absolute Error': np.float64(5.015875480582532e-06),
#    'Explained Variance': 0.07635305368033629},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.750647502387206e-09,
#    'RMSE': np.float64(9.874536699201237e-05),
#    'MAE': 2.6916030381624606e-05,
#    'R2': 0.06895412712543014,
#    'Median Absolute Error': np.float64(4.717960158266379e-06),
#    'Explained Variance': 0.06895852142672143},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.644483235571743e-09,
#    'RMSE': np.float64(9.820632991600767e-05),
#    'MAE': 2.725261602440143e-05,
#    'R2': 0.07909127980591546,
#    'Median Absolute Error': np.float64(5.228892494099272e-06),
#    'Explained Variance': 0.07910153172682621},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.743597908307587e-09,
#    'RMSE': np.float64(9.87096647158098e-05),
#    'MAE': 2.68716920403778e-05,
#    'R2': 0.06962726144514209,
#    'Median Absolute Error': np.float64(4.820274649067425e-06),
#    'Explained Variance': 0.06963099881938983},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 3,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 9.641029994602709e-09,
#    'RMSE': np.float64(9.81887467819134e-05),
#    'MAE': 2.7228227516262196e-05,
#    'R2': 0.07942101439548732,
#    'Median Absolute Error': np.float64(5.224246774109149e-06),
#    'Explained Variance': 0.07943114624564718},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_3_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2701088280990102e-08,
#    'RMSE': np.float64(0.00011269910505851455),
#    'MAE': 2.9122609433440226e-05,
#    'R2': 0.06773064980511967,
#    'Median Absolute Error': np.float64(7.3398535336996294e-06),
#    'Explained Variance': 0.0677583371437519},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2798144827979266e-08,
#    'RMSE': np.float64(0.0001131288859132771),
#    'MAE': 2.9439078237314614e-05,
#    'R2': 0.060606626887400705,
#    'Median Absolute Error': np.float64(7.370710207740924e-06),
#    'Explained Variance': 0.0606298028999388},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2714574067282188e-08,
#    'RMSE': np.float64(0.00011275892012289843),
#    'MAE': 2.9153848585584658e-05,
#    'R2': 0.06674078303581255,
#    'Median Absolute Error': np.float64(7.323971071760561e-06),
#    'Explained Variance': 0.06677073386464916},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2922825995678914e-08,
#    'RMSE': np.float64(0.00011367860834686056),
#    'MAE': 2.9457570614423502e-05,
#    'R2': 0.05145493621166042,
#    'Median Absolute Error': np.float64(7.3527187918478e-06),
#    'Explained Variance': 0.05148067256956457},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2824947864161074e-08,
#    'RMSE': np.float64(0.00011324728634347524),
#    'MAE': 2.9388118772532256e-05,
#    'R2': 0.058639264046386086,
#    'Median Absolute Error': np.float64(7.41360530877119e-06),
#    'Explained Variance': 0.058661994023813446},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2945906564209522e-08,
#    'RMSE': np.float64(0.00011378007982159936),
#    'MAE': 2.9645434246341554e-05,
#    'R2': 0.04976080527184468,
#    'Median Absolute Error': np.float64(7.488388345829812e-06),
#    'Explained Variance': 0.04978065077579363},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2868080312350075e-08,
#    'RMSE': np.float64(0.00011343756129408846),
#    'MAE': 2.9421672539698372e-05,
#    'R2': 0.055473310188270064,
#    'Median Absolute Error': np.float64(7.411731439317498e-06),
#    'Explained Variance': 0.05549896837111046},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.29713970377134e-08,
#    'RMSE': np.float64(0.00011389204115175652),
#    'MAE': 2.958869609669356e-05,
#    'R2': 0.04788978551008216,
#    'Median Absolute Error': np.float64(7.368241276868842e-06),
#    'Explained Variance': 0.04790810977546822},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.289584179445032e-08,
#    'RMSE': np.float64(0.00011355985996138918),
#    'MAE': 2.7916765960584352e-05,
#    'R2': 0.05343559670219189,
#    'Median Absolute Error': np.float64(6.0761035464182675e-06),
#    'Explained Variance': 0.053442899310989556},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2724861882600812e-08,
#    'RMSE': np.float64(0.00011280452953051492),
#    'MAE': 2.8513777098213086e-05,
#    'R2': 0.06598564972047494,
#    'Median Absolute Error': np.float64(6.683560131871237e-06),
#    'Explained Variance': 0.06599779717228149},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.289682215007563e-08,
#    'RMSE': np.float64(0.00011356417635009569),
#    'MAE': 2.7938041820835673e-05,
#    'R2': 0.05336363786830711,
#    'Median Absolute Error': np.float64(6.0980498252094e-06),
#    'Explained Variance': 0.053371150072321516},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2701072021889433e-08,
#    'RMSE': np.float64(0.000112699032923488),
#    'MAE': 2.8481330004826163e-05,
#    'R2': 0.06773184323523218,
#    'Median Absolute Error': np.float64(6.613031257697099e-06),
#    'Explained Variance': 0.0677430937232405},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2828629598121965e-08,
#    'RMSE': np.float64(0.00011326354046259531),
#    'MAE': 2.814934839317404e-05,
#    'R2': 0.05836902202842864,
#    'Median Absolute Error': np.float64(6.188541492242694e-06),
#    'Explained Variance': 0.0583774106170315},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2701595977771295e-08,
#    'RMSE': np.float64(0.00011270135747971848),
#    'MAE': 2.8649260564701735e-05,
#    'R2': 0.06769338448282392,
#    'Median Absolute Error': np.float64(6.7334693038954215e-06),
#    'Explained Variance': 0.0677112269445811},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2826836042467519e-08,
#    'RMSE': np.float64(0.00011325562256447809),
#    'MAE': 2.813165666643982e-05,
#    'R2': 0.058500670350802086,
#    'Median Absolute Error': np.float64(6.129331317711295e-06),
#    'Explained Variance': 0.05850846058451453},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 4,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2685540472722941e-08,
#    'RMSE': np.float64(0.00011263010464668379),
#    'MAE': 2.865592694715804e-05,
#    'R2': 0.06887187052491228,
#    'Median Absolute Error': np.float64(6.758839811053966e-06),
#    'Explained Variance': 0.06888730877028626},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_4_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.3187637955956377e-08,
#    'RMSE': np.float64(0.00015227487631239888),
#    'MAE': 3.768462084759098e-05,
#    'R2': 0.07355462373290034,
#    'Median Absolute Error': np.float64(6.603790744389326e-06),
#    'Explained Variance': 0.07356946349528892},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.3585831401919502e-08,
#    'RMSE': np.float64(0.00015357679317500904),
#    'MAE': 3.823161562797477e-05,
#    'R2': 0.05764509135305573,
#    'Median Absolute Error': np.float64(6.76696618894556e-06),
#    'Explained Variance': 0.057656683454270774},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.318613148355396e-08,
#    'RMSE': np.float64(0.00015226992967606558),
#    'MAE': 3.770656172240616e-05,
#    'R2': 0.07361481375287315,
#    'Median Absolute Error': np.float64(6.682568526980877e-06),
#    'Explained Variance': 0.0736266002207967},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.3443351674385523e-08,
#    'RMSE': np.float64(0.00015311221921971324),
#    'MAE': 3.817668390276129e-05,
#    'R2': 0.06333776626183163,
#    'Median Absolute Error': np.float64(6.762971622228397e-06),
#    'Explained Variance': 0.06335575417903627},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.3404274840663058e-08,
#    'RMSE': np.float64(0.00015298455752350647),
#    'MAE': 3.810702322510309e-05,
#    'R2': 0.0648990530125606,
#    'Median Absolute Error': np.float64(6.729465443617468e-06),
#    'Explained Variance': 0.06490905958633442},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.3815777834068603e-08,
#    'RMSE': np.float64(0.00015432361398719447),
#    'MAE': 3.8556885387964084e-05,
#    'R2': 0.048457747249344374,
#    'Median Absolute Error': np.float64(6.9790006355522006e-06),
#    'Explained Variance': 0.04846533453565782},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_5_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 5,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 2.3350256921180484e-08,
#    'RMSE': np.float64(0.00015280790856883188),
# ...
#    'Explained Variance': 0.009913387014351294},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.1875063245388511e-07,
#    'RMSE': np.float64(0.00034460213646157956),
#    'MAE': 5.398856037721314e-05,
#    'R2': 0.03148723952980148,
#    'Median Absolute Error': np.float64(4.202388604509446e-06),
#    'Explained Variance': 0.03151514426944935},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2164805419780336e-07,
#    'RMSE': np.float64(0.0003487808111089304),
#    'MAE': 5.2893946652528166e-05,
#    'R2': 0.007856292279576182,
#    'Median Absolute Error': np.float64(1.702823254798114e-06),
#    'Explained Variance': 0.007865142019804372},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.1915201333144816e-07,
#    'RMSE': np.float64(0.0003451840282102406),
#    'MAE': 5.404227021257835e-05,
#    'R2': 0.028213635897589184,
#    'Median Absolute Error': np.float64(3.930397709001254e-06),
#    'Explained Variance': 0.028242552435828072},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2128743672689497e-07,
#    'RMSE': np.float64(0.00034826345878787653),
#    'MAE': 5.331245616333027e-05,
#    'R2': 0.010797435539245948,
#    'Median Absolute Error': np.float64(3.4545963933690297e-06),
#    'Explained Variance': 0.010814933905724189},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.1822495420344492e-07,
#    'RMSE': np.float64(0.00034383855834307605),
#    'MAE': 5.5309036877990985e-05,
#    'R2': 0.03577459432473851,
#    'Median Absolute Error': np.float64(5.550996549012338e-06),
#    'Explained Variance': 0.03581215734582943},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.2082260182737578e-07,
#    'RMSE': np.float64(0.00034759545714433006),
#    'MAE': 5.333302337197523e-05,
#    'R2': 0.01458856087806093,
#    'Median Absolute Error': np.float64(3.5883766183724157e-06),
#    'Explained Variance': 0.014607743293797881},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 6,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 1.1842361544198233e-07,
#    'RMSE': np.float64(0.00034412732446288295),
#    'MAE': 5.453658532120817e-05,
#    'R2': 0.03415434236853088,
#    'Median Absolute Error': np.float64(4.194144075284581e-06),
#    'Explained Variance': 0.03419081389320189},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_6_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.648826166295444e-08,
#    'RMSE': np.float64(0.00021561136719327773),
#    'MAE': 4.716857323476871e-05,
#    'R2': 0.06837520137277986,
#    'Median Absolute Error': np.float64(8.813086552394295e-06),
#    'Explained Variance': 0.06837574858403761},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.6624875556668384e-08,
#    'RMSE': np.float64(0.00021592794065768419),
#    'MAE': 4.749270916277524e-05,
#    'R2': 0.06563745884018801,
#    'Median Absolute Error': np.float64(8.616678228280804e-06),
#    'Explained Variance': 0.06563951885469954},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.648202007505731e-08,
#    'RMSE': np.float64(0.00021559689254499313),
#    'MAE': 4.717106308305763e-05,
#    'R2': 0.0685002827989244,
#    'Median Absolute Error': np.float64(8.711145591717373e-06),
#    'Explained Variance': 0.06850126965755732},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.65309693957146e-08,
#    'RMSE': np.float64(0.00021571038314303415),
#    'MAE': 4.745172395289743e-05,
#    'R2': 0.06751933837620305,
#    'Median Absolute Error': np.float64(8.523734543279572e-06),
#    'Explained Variance': 0.0675203157322598},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.654522944636105e-08,
#    'RMSE': np.float64(0.0002157434343064953),
#    'MAE': 4.745571673496282e-05,
#    'R2': 0.06723356695054217,
#    'Median Absolute Error': np.float64(8.647508251117054e-06),
#    'Explained Variance': 0.06723522260572834},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.684612457832428e-08,
#    'RMSE': np.float64(0.0002164396557434064),
#    'MAE': 4.776533270229693e-05,
#    'R2': 0.06120362828009862,
#    'Median Absolute Error': np.float64(8.422648983904235e-06),
#    'Explained Variance': 0.06120579028574835},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.6517189378426464e-08,
#    'RMSE': np.float64(0.000215678439762593),
#    'MAE': 4.7426594784200404e-05,
#    'R2': 0.06779548993300277,
#    'Median Absolute Error': np.float64(8.66886768776489e-06),
#    'Explained Variance': 0.06779709960786395},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'gbdt',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.681162004626868e-08,
#    'RMSE': np.float64(0.00021635993170240344),
#    'MAE': 4.77796603731189e-05,
#    'R2': 0.061895099128397524,
#    'Median Absolute Error': np.float64(8.506034264385799e-06),
#    'Explained Variance': 0.06189770819066187},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_gbdt_nest_200_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.6931466837350767e-08,
#    'RMSE': np.float64(0.00021663671627254407),
#    'MAE': 4.532983118468673e-05,
#    'R2': 0.05949336934513594,
#    'Median Absolute Error': np.float64(6.469005881089707e-06),
#    'Explained Variance': 0.05949390876654648},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.6568524227551615e-08,
#    'RMSE': np.float64(0.0002157974147842175),
#    'MAE': 4.6324862972194354e-05,
#    'R2': 0.0667667395179945,
#    'Median Absolute Error': np.float64(7.471673326619627e-06),
#    'Explained Variance': 0.06676745539671536},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.690215926878914e-08,
#    'RMSE': np.float64(0.0002165690635081316),
#    'MAE': 4.531201718246771e-05,
#    'R2': 0.060080693041114075,
#    'Median Absolute Error': np.float64(6.5816166727185805e-06),
#    'Explained Variance': 0.06008103477506044},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 100,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.657526760285839e-08,
#    'RMSE': np.float64(0.00021581303853766202),
#    'MAE': 4.628196191406782e-05,
#    'R2': 0.06663160227178411,
#    'Median Absolute Error': np.float64(7.381296657489576e-06),
#    'Explained Variance': 0.0666322458631613},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_100_maxd_20_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.676266084046958e-08,
#    'RMSE': np.float64(0.00021624675914443106),
#    'MAE': 4.568176062766755e-05,
#    'R2': 0.06287624164936811,
#    'Median Absolute Error': np.float64(6.744056139667743e-06),
#    'Explained Variance': 0.06287728498214262},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 10,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.649041034066643e-08,
#    'RMSE': np.float64(0.00021561634989180766),
#    'MAE': 4.6518815282423573e-05,
#    'R2': 0.06833214186981851,
#    'Median Absolute Error': np.float64(7.505120596401782e-06),
#    'Explained Variance': 0.06833311591589997},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_10_lr_0.1_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.05,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.6786573800642905e-08,
#    'RMSE': np.float64(0.0002163020429876771),
#    'MAE': 4.569544659886936e-05,
#    'R2': 0.06239702590954177,
#    'Median Absolute Error': np.float64(6.904379726065131e-06),
#    'Explained Variance': 0.062397998537204846},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.05_leaves_31.json'},
#  {'eval_pair': 7,
#   'target': 'px_imp_5',
#   'boosting_type': 'dart',
#   'n_estimators': 200,
#   'max_depth': 20,
#   'learning_rate': 0.1,
#   'num_leaves': 31,
#   'metrics': {'MSE': 4.649886942228594e-08,
#    'RMSE': np.float64(0.00021563596504824037),
#    'MAE': 4.6401951006562405e-05,
#    'R2': 0.06816262186781286,
#    'Median Absolute Error': np.float64(7.467843352516705e-06),
#    'Explained Variance': 0.06816330386944902},
#   'model_file': '/data/workspace_files/Models/GBT/model_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.pkl',
#   'metrics_file': '/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_7_boost_dart_nest_200_maxd_20_lr_0.1_leaves_31.json'}]

# %%
gbt_boosting_types  = ['gbdt', 'dart']
gbt_n_estimators    = [100, 200, 1000]
gbt_max_depths      = [10, 20]
gbt_learning_rates  = [0.05, 0.1]
gbt_num_leaves      = [31]
result = {}

for method in gbt_boosting_types:
    for nest in gbt_n_estimators:
        for depth in gbt_max_depths:
            for rate in gbt_learning_rates:
                for leaf in gbt_num_leaves:
                    result[f'{method}-{nest}-{depth}-{rate}-{leaf}'] = 0
                    for eval_pair in range(1, 8):
                        filename = f"/data/workspace_files/Metrics/GBT/metrics_gbt_px_imp_5_pair_{eval_pair}_boost_{method}_nest_{nest}_maxd_{depth}_lr_{rate}_leaves_{leaf}.json"
                        with open(filename, 'r') as file:
                            data = json.load(file)
                        result[f'{method}-{nest}-{depth}-{rate}-{leaf}'] += data['R2'] / 7

# %% [markdown]
# ### XGBoost Model

# %%
os.environ["OMP_NUM_THREADS"] = str(os.cpu_count())

# %%
# Directories for saving models and metrics.
model_save_dir = '/data/workspace_files/Models/XGB'
metrics_save_dir = '/data/workspace_files/Metrics/XGB'
os.makedirs(model_save_dir, exist_ok=True)
os.makedirs(metrics_save_dir, exist_ok=True)

# Hyperparameter grids for XGBoost.
xgb_max_depths = [5, 10, 20]               # 3 values
xgb_learning_rates = [0.05, 0.1]            # 2 values
xgb_min_child_weights = [1]               # 1 value (fixed)
xgb_subsamples = [0.8, 1.0]                # 2 values
xgb_num_boost_rounds = [100, 200]           # 2 values

# Create the full grid using itertools.product.
hyperparameter_grid = list(itertools.product(
    xgb_max_depths, xgb_learning_rates, xgb_min_child_weights, xgb_subsamples, xgb_num_boost_rounds
))
print(f"Total grid points: {len(hyperparameter_grid)}")  # Expected: 24 grid points.

model_files_info = []

# Loop over evaluation pairs.
for i, (train_path, test_path) in enumerate(eval_pairs, start=1):
    for target in target_cols:
        print(f"\nProcessing target '{target}' for Eval Pair {i}")
        for max_depth, learning_rate, min_child_weight, subsample, num_boost_round in hyperparameter_grid:
            # Print the current hyperparameter set.
            print(f"  Training XGB with max_depth={max_depth}, learning_rate={learning_rate}, "
                  f"min_child_weight={min_child_weight}, subsample={subsample}, num_boost_round={num_boost_round}...")
            
            # --- Time the training step ---
            train_start = time.time()
            booster = train_xgb_model(
                train_path, predictor_cols, target,
                params={
                    'max_depth': max_depth,
                    'learning_rate': learning_rate,
                    'min_child_weight': min_child_weight,
                    'subsample': subsample
                },
                num_boost_round=num_boost_round
            )
            train_time = time.time() - train_start
            print(f"    Training time: {train_time:.4f} seconds")
            
            # Build filename that includes target, evaluation pair, and hyperparameters.
            model_filename = os.path.join(
                model_save_dir,
                f"model_xgb_{target}_pair_{i}_maxd_{max_depth}_lr_{learning_rate}_sub_{subsample}_nbr_{num_boost_round}.pkl"
            )
            
            # Save the trained model.
            with open(model_filename, 'wb') as f:
                pickle.dump(booster, f)
            print(f"    Model dumped to {model_filename}")
            
            # Record info for later evaluation.
            info = {
                'eval_pair': i,
                'target': target,
                'train_path': train_path,
                'test_path': test_path,
                'max_depth': max_depth,
                'learning_rate': learning_rate,
                'min_child_weight': min_child_weight,
                'subsample': subsample,
                'num_boost_round': num_boost_round,
                'model_file': model_filename
            }
            model_files_info.append(info)
            
            # Clean up GPU memory.
            gc.collect()
            cp.get_default_memory_pool().free_all_blocks()
            cp.get_default_pinned_memory_pool().free_all_blocks()
            cp.cuda.Stream.null.synchronize()

print("\nGrid search for XGBoost models completed.")
# Out:
# Total grid points: 24
#
# Processing target 'px_imp_5' for Eval Pair 1
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 54.1709 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 85.5217 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 52.8316 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 68.3405 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 35.1136 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 39.8121 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 28.3957 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 38.3552 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 35.2030 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 46.4469 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 35.3453 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 46.0687 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 30.2112 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 42.9071 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 29.6326 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 40.3365 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 37.8887 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 49.3089 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 38.1213 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 48.6205 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 31.3940 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 42.9955 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 30.8400 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 41.1283 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_1_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Processing target 'px_imp_5' for Eval Pair 2
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 34.0435 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 46.6420 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 34.2103 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 51.7068 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 32.0955 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 44.5907 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 30.2400 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 41.6992 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 37.5487 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 49.5583 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 43.8692 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 49.2303 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 32.0571 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 54.1729 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 31.3493 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 49.8398 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 40.7438 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 50.8268 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 38.9524 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 63.5867 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 32.9524 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 55.4585 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 32.8437 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 47.1190 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_2_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Processing target 'px_imp_5' for Eval Pair 3
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 27.6624 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 40.3521 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 26.3379 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 33.9363 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 23.0115 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 31.9703 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 23.3786 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 33.4367 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 27.3707 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 36.4805 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 31.5191 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 36.6579 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 23.7085 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 32.4692 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 23.6065 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 32.6264 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 33.4251 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 41.1453 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 28.2789 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 37.3396 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 24.7395 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 37.1267 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 28.2309 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 36.6141 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Processing target 'px_imp_5' for Eval Pair 4
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 31.0652 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 45.6660 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 25.7145 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 35.5065 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 24.3890 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 32.7753 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 22.6983 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 31.9031 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 33.6920 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 37.0851 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 30.7556 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 37.4733 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 24.4054 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 33.5428 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 24.0400 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 33.6700 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 33.7683 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 41.7755 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 31.1342 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 38.0673 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 26.0302 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 34.0380 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 24.7551 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 33.7240 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_4_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Processing target 'px_imp_5' for Eval Pair 5
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 36.7456 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 49.7410 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 30.3417 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 42.7807 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 28.1378 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 39.7935 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 27.8630 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 38.1317 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 33.9488 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 45.7342 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 35.9463 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 44.8479 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 30.4112 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 40.2790 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 29.2936 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 39.1944 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 35.7670 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 47.2755 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 41.5758 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 53.4092 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 29.5114 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 40.6722 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 31.5016 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 41.4340 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_5_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Processing target 'px_imp_5' for Eval Pair 6
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 28.5237 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 42.3086 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 28.7628 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 46.4380 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 27.4438 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 42.5675 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 27.7643 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 40.6798 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 33.9207 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 49.2679 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 33.3869 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 46.7086 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 30.2806 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 44.0787 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 29.9170 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 39.7104 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 45.9476 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 59.9057 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 45.7213 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 46.2730 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 36.3068 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 46.4172 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 28.8844 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 33.8528 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_6_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Processing target 'px_imp_5' for Eval Pair 7
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 28.4469 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 31.7869 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 20.8962 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 25.9056 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 18.3252 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 23.1783 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 18.6439 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=5, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 21.8384 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_5_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 23.3857 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 30.7069 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 25.1948 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 28.2448 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 26.7718 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 33.4069 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 23.7704 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=10, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 34.3174 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_10_lr_0.1_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 31.9186 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.05_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 49.7196 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.05_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 32.6137 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.05_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.05, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 42.3295 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.05_sub_1.0_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=100...
#     Training time: 30.7382 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.1_sub_0.8_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=0.8, num_boost_round=200...
#     Training time: 35.2753 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.1_sub_0.8_nbr_200.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=100...
#     Training time: 26.0363 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.1_sub_1.0_nbr_100.pkl
#   Training XGB with max_depth=20, learning_rate=0.1, min_child_weight=1, subsample=1.0, num_boost_round=200...
#     Training time: 34.4887 seconds
#     Model dumped to /data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_7_maxd_20_lr_0.1_sub_1.0_nbr_200.pkl
#
# Grid search for XGBoost models completed.

# %%
gc.collect()
cp.get_default_memory_pool().free_all_blocks()
cp.get_default_pinned_memory_pool().free_all_blocks()
cp.cuda.Stream.null.synchronize()

# %%
import itertools
def populate_model_files_info_from_eval_pairs_xgb(model_save_dir, eval_pairs):
    # Hyperparameter grids for XGBoost.
    xgb_max_depths = [5, 10, 20]               # 3 values
    xgb_learning_rates = [0.05, 0.1]            # 2 values
    xgb_min_child_weights = [1]               # 1 value (fixed)
    xgb_subsamples = [0.8, 1.0]                # 2 values
    xgb_num_boost_rounds = [100, 200]           # 2 values

    model_files_info = []
    target_cols = ['px_imp_5']

    # Create the full grid using itertools.product.
    hyperparameter_grid = list(itertools.product(
        xgb_max_depths, xgb_learning_rates, xgb_min_child_weights, xgb_subsamples, xgb_num_boost_rounds
    ))
    print(f"Total grid points: {len(hyperparameter_grid)}")  # Expected: 24 grid points.

    # Loop over evaluation pairs.
    for i, (train_path, test_path) in enumerate(eval_pairs, start=1):
        for target in target_cols:
            print(f"\nProcessing target '{target}' for Eval Pair {i}")
            for max_depth, learning_rate, min_child_weight, subsample, num_boost_round in hyperparameter_grid:

                # Build filename that includes target, evaluation pair, and hyperparameters.
                model_filename = os.path.join(
                    model_save_dir,
                    f"model_xgb_{target}_pair_{i}_maxd_{max_depth}_lr_{learning_rate}_sub_{subsample}_nbr_{num_boost_round}.pkl"
                )
            
                # Record info for later evaluation.
                info = {
                    'eval_pair': i,
                    'target': target,
                    'train_path': train_path,
                    'test_path': test_path,
                    'max_depth': max_depth,
                    'learning_rate': learning_rate,
                    'min_child_weight': min_child_weight,
                    'subsample': subsample,
                    'num_boost_round': num_boost_round,
                    'model_file': model_filename
                }
                model_files_info.append(info)

    return model_files_info

eval_pairs = [
    ('/data/workspace_files/train_oct/oct_train1_df.parquet', '/data/workspace_files/val_oct/oct_val1_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train2_df.parquet', '/data/workspace_files/val_oct/oct_val2_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train3_df.parquet', '/data/workspace_files/val_oct/oct_val3_df.parquet'),
    ('/data/workspace_files/train_oct/oct_train4_df.parquet', '/data/workspace_files/val_oct/oct_val4_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train5_df.parquet', '/data/workspace_files/val_nov/nov_val5_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train6_df.parquet', '/data/workspace_files/val_nov/nov_val6_df.parquet'),
    ('/data/workspace_files/train_nov/nov_train7_df.parquet', '/data/workspace_files/val_nov/nov_val7_df.parquet')
]

model_save_dir = '/data/workspace_files/Models/XGB'
metrics_save_dir = '/data/workspace_files/Metrics/XGB'
model_files_info = populate_model_files_info_from_eval_pairs_xgb(model_save_dir, eval_pairs)

len(model_files_info)


evaluation_results = []
overall_best_mse = float('inf')
overall_best_info = None

print("\nStarting evaluation loop for XGBoost models...")

total_models = len(model_files_info)
for idx, info in enumerate(model_files_info, start=1):
    print(f"\nProcessing model {idx} of {total_models}...")
    eval_pair      = info['eval_pair']
    target         = info['target']
    test_path      = info['test_path']
    max_depth      = info['max_depth']
    learning_rate  = info['learning_rate']
    min_child_weight = info.get('min_child_weight', None)
    subsample      = info.get('subsample', None)
    num_boost_round = info.get('num_boost_round', None)
    model_filename = info['model_file']
    
    # Build metrics filename.
    metrics_filename = os.path.join(
        metrics_save_dir, 
        f"metrics_xgb_{target}_pair_{eval_pair}_maxd_{max_depth}_lr_{learning_rate}_sub_{subsample}_nbr_{num_boost_round}.json"
    )
    # If the metrics file exists, skip this model.
    # if os.path.exists(metrics_filename):
    #     print(f"Metrics file {metrics_filename} already exists. Skipping model {idx}.")
    #     continue

    # --- Time the model load ---
    load_start = time.time()
    with open(model_filename, 'rb') as f:
        booster = pickle.load(f)
    load_time = time.time() - load_start
    print(f"Model load time: {load_time:.4f} seconds")
    
    # --- Time the prediction step (inside evaluate_xgb_model) ---
    pred_start = time.time()
    metrics = evaluate_xgb_model(booster, test_path, predictor_cols, target)
    pred_time = time.time() - pred_start
    print(f"Prediction time: {pred_time:.4f} seconds")
    
    # Ensure the directory for the metrics file exists.
    os.makedirs(os.path.dirname(metrics_filename), exist_ok=True)
    with open(metrics_filename, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    run_info = {
        'eval_pair': eval_pair,
        'target': target,
        'max_depth': max_depth,
        'learning_rate': learning_rate,
        'min_child_weight': min_child_weight,
        'subsample': subsample,
        'num_boost_round': num_boost_round,
        'metrics': metrics,
        'model_file': model_filename,
        'metrics_file': metrics_filename,
        'load_time': load_time,
        'prediction_time': pred_time
    }
    evaluation_results.append(run_info)
    
    # Update overall best if current MSE is lower.
    if metrics['MSE'] < overall_best_mse:
        overall_best_mse = metrics['MSE']
        overall_best_info = run_info
    
    # Clean up.
    gc.collect()

print("\nEvaluation loop for XGBoost models completed.")
# Out:
# Total grid points: 24
#
# Processing target 'px_imp_5' for Eval Pair 1
#
# Processing target 'px_imp_5' for Eval Pair 2
#
# Processing target 'px_imp_5' for Eval Pair 3
#
# Processing target 'px_imp_5' for Eval Pair 4
#
# Processing target 'px_imp_5' for Eval Pair 5
#
# Processing target 'px_imp_5' for Eval Pair 6
#
# Processing target 'px_imp_5' for Eval Pair 7
# 168

# %%
overall_best_info
# Out:
# {'eval_pair': 3,
#  'target': 'px_imp_5',
#  'max_depth': 5,
#  'learning_rate': 0.05,
#  'min_child_weight': 1,
#  'subsample': 1.0,
#  'num_boost_round': 200,
#  'metrics': {'MSE': 9.77808097461826e-09,
#   'RMSE': np.float64(9.888417959723517e-05),
#   'MAE': 2.797008637131759e-05,
#   'R2': 0.06633462712883109,
#   'Median Absolute Error': np.float64(6.003017460898263e-06),
#   'Explained Variance': 0.06634413949745366},
#  'model_file': '/data/workspace_files/Models/XGB/model_xgb_px_imp_5_pair_3_maxd_5_lr_0.05_sub_1.0_nbr_200.pkl',
#  'metrics_file': '/data/workspace_files/Metrics/XGB/metrics_xgb_px_imp_5_pair_3_maxd_5_lr_0.05_sub_1.0_nbr_200.json',
#  'load_time': 0.03071451187133789,
#  'prediction_time': 10.899120330810547}

# %% [markdown]
# ### LSTM

# %%
# Ensure the checkpoint directory exists.
checkpoint_dir = '/data/workspace_files/Models/LSTM'
os.makedirs(checkpoint_dir, exist_ok=True)
model_save_path = os.path.join(checkpoint_dir, 'lstm_checkpoint.pt')

# %%
predictor_cols = [
    'bid', 'spread_minus', 'bbo_moving_trade', 'non_bbo_moving_trade', 'bbo_improving_limit',
    'bbo_worsening_cancel', 'bbo_depth_add_limit', 'bbo_depth_remove_cancel',
    'non_bbo_depth_add_limit', 'non_bbo_depth_remove_cancel', 'non_bbo_deep_depth_add_limit',
    'non_bbo_deep_depth_remove_cancel', 'bbo_depth_imbalance_minus', 
    'non_bbo_depth_imbalance_minus', 'non_bbo_deep_depth_imbalance_minus', 
    'bbo_queue_length_immbalance_minus', 'block_2', 'block_3', 'block_4', 'block_5', 'block_6'
]

# Additional observable features and their replicates.
ob_features = [
    'bbo_moving_trade', 'non_bbo_moving_trade', 'bbo_improving_limit',
    'bbo_worsening_cancel', 'bbo_depth_add_limit', 'bbo_depth_remove_cancel',
    'non_bbo_depth_add_limit', 'non_bbo_depth_remove_cancel', 
    'non_bbo_deep_depth_add_limit', 'non_bbo_deep_depth_remove_cancel'
]
for feat in ob_features:
    for r in range(1, 4):
        predictor_cols.append(f'{feat}_{r}')

target_col = 'px_imp_5'

# Define file paths.
eval_pairs = [('/data/workspace_files/train_oct/oct_train1_df.parquet', '/data/workspace_files/val_oct/oct_val1_df.parquet'),
              ('/data/workspace_files/train_oct/oct_train2_df.parquet', '/data/workspace_files/val_oct/oct_val2_df.parquet'),
              ('/data/workspace_files/train_oct/oct_train3_df.parquet', '/data/workspace_files/val_oct/oct_val3_df.parquet'),
              ('/data/workspace_files/train_oct/oct_train4_df.parquet', '/data/workspace_files/val_oct/oct_val4_df.parquet'),
              ('/data/workspace_files/train_nov/nov_train5_df.parquet', '/data/workspace_files/val_nov/nov_val5_df.parquet'),
              ('/data/workspace_files/train_nov/nov_train6_df.parquet', '/data/workspace_files/val_nov/nov_val6_df.parquet'),
              ('/data/workspace_files/train_nov/nov_train7_df.parquet', '/data/workspace_files/val_nov/nov_val7_df.parquet')]

# %%
# Define the LSTM model for regression.
class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim=64, num_layers=2, output_dim=1, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_dim, output_dim)
    
    def forward(self, x):
        x = x.unsqueeze(1)
        lstm_out, _ = self.lstm(x)
        last_out = lstm_out[:, -1, :]
        out = self.fc(last_out)
        return out

def train_lstm_model(eval_pairs, predictor_cols, target_col, 
                     num_epochs=10, batch_size=64, learning_rate=0.001, 
                     num_eval_epochs=1,  # Set to 0 to skip eval fine-tuning.
                     model_save_path=model_save_path):
    """
    Train an LSTM model on each eval pair with incremental checkpointing.
    
    For each eval pair:
      - Train on the training set for 'num_epochs' (or resume if partially completed).
      - Evaluate on the validation set.
      - Optionally perform additional training on the validation set for 'num_eval_epochs'.
    
    The checkpoint saved contains:
      - current_pair_index: which eval pair we're on.
      - current_epoch: if < num_epochs, this is in the training phase;
          if >= num_epochs, then (current_epoch - num_epochs) eval epochs have been completed.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    input_dim = len(predictor_cols)
    
    # Initialize the model.
    model = LSTMModel(input_dim=input_dim).to(device)
    # Freeze LSTM layer parameters.
    for param in model.lstm.parameters():
        param.requires_grad = False
    # Only parameters in the fully connected layer are trainable.
    optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=learning_rate)
    criterion = nn.MSELoss()

    # Check if a checkpoint exists.
    start_pair = 0
    current_epoch = 0  # Represents the last completed epoch (training + eval fine-tuning) for current eval pair.
    if os.path.exists(model_save_path):
        checkpoint = torch.load(model_save_path)
        model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_pair = checkpoint.get('current_pair_index', 0)
        current_epoch = checkpoint.get('current_epoch', 0)
        print(f"Checkpoint found. Resuming from eval pair index {start_pair}, current_epoch {current_epoch}")
    else:
        print("No checkpoint found. Starting fresh training.")

    # Process each eval pair.
    for idx, (train_path, val_path) in enumerate(eval_pairs[start_pair:], start=start_pair):
        print(f"\n--- Starting eval pair index {idx} ---")
        # ----------------- Training Phase on Training Set -----------------
        # Load training data.
        train_df = pd.read_parquet(train_path, columns=predictor_cols + [target_col])
        X_train = torch.tensor(train_df[predictor_cols].values, dtype=torch.float32)
        y_train = torch.tensor(train_df[target_col].values, dtype=torch.float32)
        train_dataset = TensorDataset(X_train, y_train)
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
        
        if current_epoch < num_epochs:
            for epoch in range(current_epoch, num_epochs):
                model.train()
                epoch_losses = []
                for X_batch, y_batch in train_loader:
                    X_batch = X_batch.to(device)
                    y_batch = y_batch.to(device)
                    optimizer.zero_grad()
                    predictions = model(X_batch)
                    loss = criterion(predictions.squeeze(), y_batch.squeeze())
                    loss.backward()
                    optimizer.step()
                    epoch_losses.append(loss.item())
                avg_loss = sum(epoch_losses) / len(epoch_losses)
                print(f"Eval Pair {idx} - Training Epoch {epoch+1}/{num_epochs}: Loss = {avg_loss:.4f}")
                
                # Update checkpoint after each training epoch.
                current_epoch = epoch + 1
                checkpoint = {
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'current_pair_index': idx,
                    'current_epoch': current_epoch
                }
                torch.save(checkpoint, model_save_path)
                print(f"Checkpoint saved after training epoch {current_epoch} for eval pair {idx}.")
        else:
            print(f"Training phase already complete for eval pair {idx}.")


        # ----------------- Cleanup Before Evaluation -----------------
        del train_df, X_train, y_train, train_dataset, train_loader
        gc.collect()
        torch.cuda.empty_cache()
        time.sleep(1)  # Short delay to ensure GPU memory is freed
        
        # ----------------- Evaluation on Validation Set -----------------
        # Load validation data into CPU memory first.
        val_df = pd.read_parquet(val_path, columns=predictor_cols + [target_col])
        X_val_cpu = torch.tensor(val_df[predictor_cols].values, dtype=torch.float32)
        y_val_cpu = torch.tensor(val_df[target_col].values, dtype=torch.float32)
        val_dataset = TensorDataset(X_val_cpu, y_val_cpu)
        # Use a DataLoader so we only load one batch at a time onto the GPU.
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
        
        model.eval()
        total_loss = 0.0
        count = 0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                predictions = model(X_batch)
                loss = criterion(predictions.squeeze(), y_batch.squeeze())
                total_loss += loss.item() * X_batch.size(0)
                count += X_batch.size(0)
        avg_val_loss = total_loss / count
        print(f"Eval Pair {idx}: Validation Loss = {avg_val_loss:.4f}")
        
        # ----------------- Additional Training on Validation Set (Fine-Tuning) -----------------
        if num_eval_epochs > 0:
            # Reuse the same val_loader for fine-tuning.
            # Determine eval epochs already done:
            eval_epochs_done = max(0, current_epoch - num_epochs)
            for eval_epoch in range(eval_epochs_done, num_eval_epochs):
                model.train()
                eval_epoch_losses = []
                for X_batch, y_batch in val_loader:
                    X_batch = X_batch.to(device)
                    y_batch = y_batch.to(device)
                    optimizer.zero_grad()
                    predictions = model(X_batch)
                    loss = criterion(predictions.squeeze(), y_batch.squeeze())
                    loss.backward()
                    optimizer.step()
                    eval_epoch_losses.append(loss.item())
                avg_eval_loss = sum(eval_epoch_losses) / len(eval_epoch_losses)
                print(f"Eval Pair {idx} - Fine-Tuning Epoch {eval_epoch+1}/{num_eval_epochs}: Loss = {avg_eval_loss:.4f}")
                
                current_epoch = num_epochs + eval_epoch + 1
                checkpoint = {
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'current_pair_index': idx,
                    'current_epoch': current_epoch
                }
                torch.save(checkpoint, model_save_path)
                print(f"Checkpoint saved after fine-tuning epoch {eval_epoch+1} for eval pair {idx}.")
            del val_loader
        else:
            print("Skipping fine-tuning on eval set (num_eval_epochs is 0).")
        
        # Cleanup validation data.
        del val_df, X_val_cpu, y_val_cpu, val_dataset
        gc.collect()
        torch.cuda.empty_cache()
        time.sleep(1)
        
        # Mark completion of this eval pair and reset current_epoch.
        current_epoch = 0
        checkpoint = {
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'current_pair_index': idx + 1,
            'current_epoch': current_epoch
        }
        torch.save(checkpoint, model_save_path)
        print(f"Completed eval pair {idx}. Checkpoint updated for next pair.")
        
        torch.cuda.empty_cache()
        time.sleep(1)

    print(f"\nFinal model saved to {model_save_path}")
    return model

# %%
model = train_lstm_model(
    eval_pairs,
    predictor_cols,
    target_col,
    num_epochs=10,
    batch_size=256,
    learning_rate=0.001,
    num_eval_epochs=10,
    model_save_path=model_save_path
)
# Out:
# Checkpoint found. Resuming from eval pair index 3, current_epoch 8
#
# --- Starting eval pair index 3 ---
# Eval Pair 3 - Training Epoch 9/10: Loss = 0.0000
# Checkpoint saved after training epoch 9 for eval pair 3.
# Eval Pair 3 - Training Epoch 10/10: Loss = 0.0000
# Checkpoint saved after training epoch 10 for eval pair 3.
# Eval Pair 3: Validation Loss = 0.0000
# Eval Pair 3 - Fine-Tuning Epoch 1/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 1 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 2/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 2 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 3/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 3 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 4/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 4 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 5/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 5 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 6/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 6 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 7/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 7 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 8/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 8 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 9/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 9 for eval pair 3.
# Eval Pair 3 - Fine-Tuning Epoch 10/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 10 for eval pair 3.
# Completed eval pair 3. Checkpoint updated for next pair.
#
# --- Starting eval pair index 4 ---
# Eval Pair 4 - Training Epoch 1/10: Loss = 0.0000
# Checkpoint saved after training epoch 1 for eval pair 4.
# Eval Pair 4 - Training Epoch 2/10: Loss = 0.0000
# Checkpoint saved after training epoch 2 for eval pair 4.
# Eval Pair 4 - Training Epoch 3/10: Loss = 0.0000
# Checkpoint saved after training epoch 3 for eval pair 4.
# Eval Pair 4 - Training Epoch 4/10: Loss = 0.0000
# Checkpoint saved after training epoch 4 for eval pair 4.
# Eval Pair 4 - Training Epoch 5/10: Loss = 0.0000
# Checkpoint saved after training epoch 5 for eval pair 4.
# Eval Pair 4 - Training Epoch 6/10: Loss = 0.0000
# Checkpoint saved after training epoch 6 for eval pair 4.
# Eval Pair 4 - Training Epoch 7/10: Loss = 0.0000
# Checkpoint saved after training epoch 7 for eval pair 4.
# Eval Pair 4 - Training Epoch 8/10: Loss = 0.0000
# Checkpoint saved after training epoch 8 for eval pair 4.
# Eval Pair 4 - Training Epoch 9/10: Loss = 0.0000
# Checkpoint saved after training epoch 9 for eval pair 4.
# Eval Pair 4 - Training Epoch 10/10: Loss = 0.0000
# Checkpoint saved after training epoch 10 for eval pair 4.
# Eval Pair 4: Validation Loss = 0.0000
# Eval Pair 4 - Fine-Tuning Epoch 1/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 1 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 2/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 2 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 3/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 3 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 4/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 4 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 5/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 5 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 6/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 6 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 7/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 7 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 8/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 8 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 9/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 9 for eval pair 4.
# Eval Pair 4 - Fine-Tuning Epoch 10/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 10 for eval pair 4.
# Completed eval pair 4. Checkpoint updated for next pair.
#
# --- Starting eval pair index 5 ---
# Eval Pair 5 - Training Epoch 1/10: Loss = 0.0000
# Checkpoint saved after training epoch 1 for eval pair 5.
# Eval Pair 5 - Training Epoch 2/10: Loss = 0.0000
# Checkpoint saved after training epoch 2 for eval pair 5.
# Eval Pair 5 - Training Epoch 3/10: Loss = 0.0000
# Checkpoint saved after training epoch 3 for eval pair 5.
# Eval Pair 5 - Training Epoch 4/10: Loss = 0.0000
# Checkpoint saved after training epoch 4 for eval pair 5.
# Eval Pair 5 - Training Epoch 5/10: Loss = 0.0000
# Checkpoint saved after training epoch 5 for eval pair 5.
# Eval Pair 5 - Training Epoch 6/10: Loss = 0.0000
# Checkpoint saved after training epoch 6 for eval pair 5.
# Eval Pair 5 - Training Epoch 7/10: Loss = 0.0000
# Checkpoint saved after training epoch 7 for eval pair 5.
# Eval Pair 5 - Training Epoch 8/10: Loss = 0.0000
# Checkpoint saved after training epoch 8 for eval pair 5.
# Eval Pair 5 - Training Epoch 9/10: Loss = 0.0000
# Checkpoint saved after training epoch 9 for eval pair 5.
# Eval Pair 5 - Training Epoch 10/10: Loss = 0.0000
# Checkpoint saved after training epoch 10 for eval pair 5.
# Eval Pair 5: Validation Loss = 0.0000
# Eval Pair 5 - Fine-Tuning Epoch 1/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 1 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 2/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 2 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 3/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 3 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 4/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 4 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 5/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 5 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 6/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 6 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 7/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 7 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 8/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 8 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 9/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 9 for eval pair 5.
# Eval Pair 5 - Fine-Tuning Epoch 10/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 10 for eval pair 5.
# Completed eval pair 5. Checkpoint updated for next pair.
#
# --- Starting eval pair index 6 ---
# Eval Pair 6 - Training Epoch 1/10: Loss = 0.0000
# Checkpoint saved after training epoch 1 for eval pair 6.
# Eval Pair 6 - Training Epoch 2/10: Loss = 0.0000
# Checkpoint saved after training epoch 2 for eval pair 6.
# Eval Pair 6 - Training Epoch 3/10: Loss = 0.0000
# Checkpoint saved after training epoch 3 for eval pair 6.
# Eval Pair 6 - Training Epoch 4/10: Loss = 0.0000
# Checkpoint saved after training epoch 4 for eval pair 6.
# Eval Pair 6 - Training Epoch 5/10: Loss = 0.0000
# Checkpoint saved after training epoch 5 for eval pair 6.
# Eval Pair 6 - Training Epoch 6/10: Loss = 0.0000
# Checkpoint saved after training epoch 6 for eval pair 6.
# Eval Pair 6 - Training Epoch 7/10: Loss = 0.0000
# Checkpoint saved after training epoch 7 for eval pair 6.
# Eval Pair 6 - Training Epoch 8/10: Loss = 0.0000
# Checkpoint saved after training epoch 8 for eval pair 6.
# Eval Pair 6 - Training Epoch 9/10: Loss = 0.0000
# Checkpoint saved after training epoch 9 for eval pair 6.
# Eval Pair 6 - Training Epoch 10/10: Loss = 0.0000
# Checkpoint saved after training epoch 10 for eval pair 6.
# Eval Pair 6: Validation Loss = 0.0000
# Eval Pair 6 - Fine-Tuning Epoch 1/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 1 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 2/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 2 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 3/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 3 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 4/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 4 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 5/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 5 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 6/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 6 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 7/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 7 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 8/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 8 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 9/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 9 for eval pair 6.
# Eval Pair 6 - Fine-Tuning Epoch 10/10: Loss = 0.0000
# Checkpoint saved after fine-tuning epoch 10 for eval pair 6.
# Completed eval pair 6. Checkpoint updated for next pair.
#
# Final model saved to /data/workspace_files/Models/LSTM/lstm_checkpoint.pt

# %%
# Set up device.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate the model.
input_dim = len(predictor_cols)
model = LSTMModel(input_dim=input_dim).to(device)

# Load the checkpoint.
checkpoint = torch.load(model_save_path)
model.load_state_dict(checkpoint['model_state_dict'])
model.eval()

# Function to predict and compute metrics for a given file.
def predict_and_compute_metrics(file_path, batch_size=256):
    # Load validation data from CPU.
    df = pd.read_parquet(file_path, columns=predictor_cols + [target_col])
    X_cpu = torch.tensor(df[predictor_cols].values, dtype=torch.float32)
    y_true = df[target_col].values  # Ground truth as NumPy array.
    
    dataset = TensorDataset(X_cpu)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    
    predictions_list = []
    with torch.no_grad():
        for batch in loader:
            batch_x = batch[0].to(device)
            preds = model(batch_x)
            predictions_list.append(preds.cpu())
    y_pred = torch.cat(predictions_list, dim=0).squeeze().numpy()
    
    metrics = compute_regression_metrics(y_true, y_pred)
    return y_true, y_pred, metrics

# Test files.
test_files = [
    '/data/workspace_files/test_dec/first_week_df.parquet',
    '/data/workspace_files/test_dec/second_week_df.parquet'
]

# To store metrics for each week.
week_metrics = {}
week_predictions = {}
all_y_true = []
all_y_pred = []

for file_path in test_files:
    base_name = os.path.basename(file_path)
    print(f"Processing file: {file_path}")
    y_true, y_pred, metrics = predict_and_compute_metrics(file_path, batch_size=256)
    week_metrics[base_name] = metrics
    week_predictions[base_name] = y_pred.tolist()  # Convert NumPy array to list.
    all_y_true.append(y_true)
    all_y_pred.append(y_pred)
    print(f"Metrics for {base_name}: {metrics}")
    torch.cuda.empty_cache()
    gc.collect()
    time.sleep(1)

# Aggregate results across all test files.
agg_y_true = np.concatenate(all_y_true)
agg_y_pred = np.concatenate(all_y_pred)
aggregated_metrics = compute_regression_metrics(agg_y_true, agg_y_pred)

print("\nAggregated Metrics for Entire Test Set:")
print(aggregated_metrics)

# Prepare results to save.
results = {
    "week_metrics": week_metrics,
    "aggregated_metrics": aggregated_metrics,
    "week_predictions": week_predictions
}

# Save results to a JSON file in the LSTM folder.
results_json_path = os.path.join(checkpoint_dir, "test_results.json")
with open(results_json_path, "w") as f:
    json.dump(results, f, indent=4)

print(f"Metrics and predictions saved to {results_json_path}")
# Out:
# Processing file: /data/workspace_files/test_dec/first_week_df.parquet
# Metrics for first_week_df.parquet: {'MSE': 1.5185416776022949e-06, 'RMSE': np.float64(0.0012322912308388367), 'MAE': 0.0009004806530252714, 'R2': -11.754886405082777, 'Median Absolute Error': np.float64(0.000488348538056016), 'Explained Variance': -6.570038105125205}
# Processing file: /data/workspace_files/test_dec/second_week_df.parquet
# Metrics for second_week_df.parquet: {'MSE': 1.5932895917378045e-06, 'RMSE': np.float64(0.0012622557552801272), 'MAE': 0.0009440433832736227, 'R2': -25.83704652117, 'Median Absolute Error': np.float64(0.0005762574170449224), 'Explained Variance': -14.036397888269919}
#
# Aggregated Metrics for Entire Test Set:
# {'MSE': 1.5565697801603443e-06, 'RMSE': np.float64(0.0012476256570623835), 'MAE': 0.0009226432510422458, 'R2': -16.550610950501998, 'Median Absolute Error': np.float64(0.0005157595562707701), 'Explained Variance': -9.120155005330588}
# Metrics and predictions saved to /data/workspace_files/Models/LSTM/test_results.json
